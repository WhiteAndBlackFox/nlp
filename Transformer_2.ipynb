# %% [markdown]
# <a href="https://colab.research.google.com/github/WhiteAndBlackFox/nlp/blob/Transform2/Transformer_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Модель Transformer-2

# %% [markdown]
# ## Доставляем библиотеки и импортируем их

# %%
# !pip install transformers transformers[sentencepiece] sentencepiece datasets sentence-transformers rouge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.20.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.96)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.3.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (2.2.2)
# Requirement already satisfied: rouge in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.8.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.5.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.0+cu113)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.0+cu113)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge) (1.15.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (3.17.3)

# %%
import pandas as pd
import numpy as np
import torch

from datasets import load_dataset

from tqdm import tqdm; tqdm.pandas()

from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import GRU, AdditiveAttention

import nltk; nltk.download('punkt')
from nltk import sent_tokenize

import unicodedata
import re
import os
import io
import time
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Скачиваем данные и подготавливаем

# %%
dataset = load_dataset('IlyaGusev/gazeta', revision="v1.0")
dataset
# Out:
# No config specified, defaulting to: gazeta/default
# Reusing dataset gazeta (/root/.cache/huggingface/datasets/IlyaGusev___gazeta/default/1.0.0/ef9349c3c0f3112ca4036520d76c4bc1b8a79d30bc29643c6cae5a094d44e457)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'summary', 'title', 'date', 'url'],
#         num_rows: 52400
#     })
#     test: Dataset({
#         features: ['text', 'summary', 'title', 'date', 'url'],
#         num_rows: 5770
#     })
#     validation: Dataset({
#         features: ['text', 'summary', 'title', 'date', 'url'],
#         num_rows: 5265
#     })
# })

# %%
df_test = pd.DataFrame(dataset["test"])
df_train = pd.DataFrame(dataset["train"])
df_test.head()
# Out:
#                                                 text  \
# 0  Американское аэрокосмическое агентство NASA ог...
# 1  Около 11 тысяч зрителей увидели все самое лучш...
# 2  7 ноября в Белоруссии прошли выборы членов сов...
# 3  Народная артистка РСФСР Надежда Бабкина в инте...
# 4  Депутат Верховной рады от партии «Слуга народа...
#
#                                              summary  \
# 0  В NASA назвали четыре миссии в дальний космос,...
# 1  25 и 26 февраля в Кремлевском дворце съездов п...
# 2  В Белоруссии в день годовщины Октябрьской рево...
# 3  Народная артистка РСФСР Надежда Бабкина в инте...
# 4  Украина не должна выплачивать пенсии жителям Д...
#
#                                                title                 date  \
# 0           Венера, Ио или Тритон: куда полетит NASA  2020-02-14 16:39:11
# 1                 «Люди в Бурятии очень талантливые»  2020-02-28 10:44:13
# 2        Вспомнить СССР: как Лукашенко провел выборы  2019-11-07 19:55:08
# 3  «Он очень переживал»: Бабкина об отношениях с ...  2020-03-01 16:50:06
# 4  «Поддерживают Россию»: почему Киев не платит п...  2020-02-06 12:41:24
#
#                                                  url
# 0  https://www.gazeta.ru/science/2020/02/14_a_129...
# 1  https://www.gazeta.ru/social/2020/02/28/129806...
# 2  https://www.gazeta.ru/politics/2019/11/07_a_12...
# 3  https://www.gazeta.ru/culture/2020/03/01/a_129...
# 4  https://www.gazeta.ru/business/2020/02/06/1294...

# %% [markdown]
# ## Дополнительные функции

# %%
def calc_scores(references, predictions, metric="all"):
  """
    Функция подсчета метрик
  """
  print("Count:", len(predictions))
  print("Ref:", references[-1])
  print("Hyp:", predictions[-1])

  if metric in ("bleu", "all"):
      print("BLEU: ", corpus_bleu([[r] for r in references], predictions))
  if metric in ("rouge", "all"):
      rouge = Rouge()
      scores = rouge.get_scores(predictions, references, avg=True)
      print("ROUGE: ", scores)

def summary_model(model_name, df_test):
  """
    Подсчет метрик на примере предсказания модели
  """
  print(f"Model: {model_name}")
  tokenizer = AutoTokenizer.from_pretrained(model_name)
  model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
  article_text = df_test['text'][1]

  input_ids = tokenizer(
      [article_text],
      max_length=600,
      add_special_tokens=True,
      padding="max_length",
      truncation=True,
      return_tensors="pt"
  )["input_ids"]

  output_ids = model.generate(
      input_ids=input_ids,
      no_repeat_ngram_size=4
  )[0]

  summary = tokenizer.decode(output_ids, skip_special_tokens=True)
  print(f"summary: {summary}\n")

  target = sent_tokenize(df_test['summary'][1])
  preds = sent_tokenize(summary)

  calc_scores(target, preds)

def loss_function(real, pred):
    """
      Функция потери
    """
    # определяем ненулевые элементы
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    #переводим mask к типу loss_
    mask = tf.cast(mask, dtype=loss_.dtype)
    #умножаем loss на маску
    loss_ *= mask

    return tf.reduce_mean(loss_) #возвращаем среднее значение элементов тензора

@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
      enc_output, enc_hidden = encoder(inp, enc_hidden)

      dec_hidden = enc_hidden

      dec_input = tf.expand_dims([sum_wordindex['bos']] * BATCH_SIZE, 1)

      # Teacher forcing - feeding the target as the next input
      for t in range(1, targ.shape[1]):
          # passing enc_output to the decoder
          predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)

          loss += loss_function(targ[:, t], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

def evaluate(sentence, tok_text, tok_sum, max_len_text = 700, max_len_sum = 100):
  """
    Оценика модели
  """
  inputs = [tok_text.word_index[i] for i in sentence.split(' ') if i !='']
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                          maxlen=max_len_text,
                                                          padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, latent_dim))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([tok_sum.word_index['bos']], 0)

  for t in range(max_len_sum):
      predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)

      predicted_id = tf.argmax(predictions[0]).numpy()

      result += tok_sum.index_word[predicted_id] + ' '

      if tok_sum.index_word[predicted_id] == 'eos':
          return result

      # the predicted ID is fed back into the model
      dec_input = tf.expand_dims([predicted_id], 0)

  return result

def seq2text(input_seq):
  """
    Функция перевода последовательности индексов в текст
  """
  newString = ''
  for i in input_seq:
      if i != 0:
          newString = newString + reverse_text_index[i] + ' '
  return newString

def seq2summary(input_seq):
  """
    Функция перевода последовательности индексов в title
  """
  newString = ''
  for i in input_seq:
      if (i != 0 and i != sum_wordindex['bos']) and i != sum_wordindex['eos']:
          newString = newString + reverse_sum_index[i] + ' '
  return newString

# %% [markdown]
# ## Глобальные параметры

# %%
MAX_TRAIN_SAMPLE = 10000
MAX_TEST_SAMPLE = 2000

EPOCHS = 200

BATCH_SIZE = 64
BUFFER_SIZE = 1

# %% [markdown]
# ## Дополнительные классы

# %%
class Transform_2():
  
  __token = None
  __text_vocab_size = None
  __seq_token = {
      "test": None,
      "train": None
  }
  __padded = {
      "test": None,
      "train": None
  }
  max_len = 0

  def __init__(self, max_len = 700):
    self.__token = Tokenizer()
    self.max_len = max_len

  def get_token(self):
    return self.__token
  
  def get_size(self):
    return self.__text_vocab_size
  
  def get_padded(self):
    return self.__padded
  
  def __eval_token(self, txt_train, txt_test):
    self.__token.fit_on_texts(txt_train)
    self.__seq_token['train'] = self.__token.texts_to_sequences(txt_train)
    self.__seq_token['test'] = self.__token.texts_to_sequences(txt_test)
  
  def transfrom_text(self, txt_train, txt_test):
    self.__eval_token(txt_train, txt_test)

    self.__text_vocab_size = len(self.__token.word_index) + 1
    self.__padded["train"] = pad_sequences(self.__seq_token['train'], maxlen=self.max_len, padding='post', truncating='post')
    self.__padded["test"] = pad_sequences(self.__seq_token['test'], maxlen=self.max_len, padding='post', truncating='post')

# %% [markdown]
# ## 1. Провериv насколько хорошо она суммаризирует модель *rut5_base_sum_gazeta*

# %%
models = ["IlyaGusev/mbart_ru_sum_gazeta", "IlyaGusev/rut5_base_sum_gazeta"]
for model in models:
  summary_model(model, df_test)
# Out:
# Model: IlyaGusev/mbart_ru_sum_gazeta
# summary: В Кремле прошла премьера новогоднего шоу «Танцуют все!» с участием более 300 артистов из одного региона. Зрителям рассказали, что в Бурятии сохранилась и развивается культура десятков национальностей, включая русских, бурятов, староверов (семейских), эвенков.
#
# Count: 2
# Ref: Бурятия - центр российского буддизма и один из немногих регионов страны, где новый год встречают официально дважды.
# Hyp: Зрителям рассказали, что в Бурятии сохранилась и развивается культура десятков национальностей, включая русских, бурятов, староверов (семейских), эвенков.
# BLEU:  0.15606720318720219
# ROUGE:  {'rouge-1': {'r': 0.029411764705882353, 'p': 0.029411764705882353, 'f': 0.02941176220588257}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.029411764705882353, 'p': 0.029411764705882353, 'f': 0.02941176220588257}}
# Model: IlyaGusev/rut5_base_sum_gazeta
# summary: В Кремле прошло праздничное шоу «Танцуют все!» на телеканале «Россия». Зрителям рассказали, что в Бурятии сохранилась и развивается культура десятков национальностей, включая русских, бурятов, староверов и эвенков.
#
# Count: 2
# Ref: Бурятия - центр российского буддизма и один из немногих регионов страны, где новый год встречают официально дважды.
# Hyp: Зрителям рассказали, что в Бурятии сохранилась и развивается культура десятков национальностей, включая русских, бурятов, староверов и эвенков.
# BLEU:  0.19334823151545613
# ROUGE:  {'rouge-1': {'r': 0.029411764705882353, 'p': 0.03125, 'f': 0.030303027805326194}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.029411764705882353, 'p': 0.03125, 'f': 0.030303027805326194}}

# %% [markdown]
# ## 2. Сделаем генерацию заголовков для статьи, т.е. обучим модель для генерацию заголовков

# %%
df_test['title_clean'] = df_test['title'].progress_apply(lambda v: 'BOS ' + v + ' EOS')
df_train['title_clean'] = df_train['title'].progress_apply(lambda v: 'BOS ' + v + ' EOS')
# Out:
# 100%|██████████| 5770/5770 [00:00<00:00, 339550.66it/s]
# 100%|██████████| 52400/52400 [00:00<00:00, 759039.93it/s]

# %%
df_train = df_train[:MAX_TRAIN_SAMPLE]
df_test = df_test[:MAX_TEST_SAMPLE]

# %%
trans_2 = Transform_2()
trans_2.transfrom_text(df_train['text'], df_test['text'])

# %%
trans_2_sum = Transform_2(100)
trans_2_sum.transfrom_text(df_train['title_clean'], df_test['title_clean'])

# %%
reverse_text_index = trans_2.get_token().index_word
reverse_sum_index = trans_2_sum.get_token().index_word
sum_wordindex = trans_2_sum.get_token().word_index

# %% [markdown]
# ### Строим модели энкодера и декодера

# %%
# Переопределяем буффер
BUFFER_SIZE = len(trans_2.get_padded()['train'])
# Переотпределяем шаг
steps_per_epoch = len(trans_2.get_padded()['train'])//BATCH_SIZE

# Каждую пару (padded_x_train, padded_x_train_sum) преобразуем в тензор
dataset = tf.data.Dataset.from_tensor_slices((trans_2.get_padded()['train'], trans_2_sum.get_padded()['train'])).shuffle(BUFFER_SIZE)
# Объединяем последоваетльные элементы в батчи, неполный батч удаляем
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 100]), TensorShape([64, 100]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru1 = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.gru2 = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru1(x, initial_state = hidden)
        output, state = self.gru2(output, initial_state = state)
        return output, state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))
    
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.attention = tf.keras.layers.AdditiveAttention()

    def call(self, x, query, value):
        # enc_output shape == (batch_size, max_length, hidden_size)
        #attention_weights = self.attention([ tf.expand_dims(query, 1), value,])
        context_vector = self.attention([tf.expand_dims(query, 1), value,])
        #context_vector = tf.squeeze(context_vector)


        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([context_vector, x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab)
        x = self.fc(output)

        return x, state

# %%
latent_dim = 300
embedding_dim=200

# создаем экземпляры encoder и decoder
encoder = Encoder(trans_2.get_size(), embedding_dim, latent_dim, BATCH_SIZE)
decoder = Decoder(trans_2_sum.get_size(), embedding_dim, latent_dim, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)

# %% [markdown]
# ### Обучаем модели

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

checkpoint_dir = './training_summ_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 10 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                     batch,
                                                     batch_loss.numpy()))
    # saving (checkpoint) the model every 50 epochs
    if (epoch + 1) % 50 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for {} epoch {} sec\n'.format(epoch + 1, time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 0.6134
# Epoch 1 Batch 10 Loss 0.5680
# Epoch 1 Batch 20 Loss 0.5290
# Epoch 1 Batch 30 Loss 0.5488
# Epoch 1 Batch 40 Loss 0.5106
# Epoch 1 Batch 50 Loss 0.5156
# Epoch 1 Batch 60 Loss 0.5311
# Epoch 1 Batch 70 Loss 0.4592
# Epoch 1 Batch 80 Loss 0.5174
# Epoch 1 Batch 90 Loss 0.4883
# Epoch 1 Batch 100 Loss 0.4783
# Epoch 1 Batch 110 Loss 0.4902
# Epoch 1 Batch 120 Loss 0.5179
# Epoch 1 Batch 130 Loss 0.4986
# Epoch 1 Batch 140 Loss 0.4517
# Epoch 1 Batch 150 Loss 0.5108
# Epoch 1 Loss 0.5125
# Time taken for 1 epoch 183.75846195220947 sec
#
# Epoch 2 Batch 0 Loss 0.4600
# Epoch 2 Batch 10 Loss 0.4766
# Epoch 2 Batch 20 Loss 0.4633
# Epoch 2 Batch 30 Loss 0.4564
# Epoch 2 Batch 40 Loss 0.4267
# Epoch 2 Batch 50 Loss 0.4724
# Epoch 2 Batch 60 Loss 0.4515
# Epoch 2 Batch 70 Loss 0.4936
# Epoch 2 Batch 80 Loss 0.4899
# Epoch 2 Batch 90 Loss 0.4396
# Epoch 2 Batch 100 Loss 0.4691
# Epoch 2 Batch 110 Loss 0.4636
# Epoch 2 Batch 120 Loss 0.4357
# Epoch 2 Batch 130 Loss 0.5025
# Epoch 2 Batch 140 Loss 0.4717
# Epoch 2 Batch 150 Loss 0.4512
# Epoch 2 Loss 0.4654
# Time taken for 2 epoch 52.483810901641846 sec
#
# Epoch 3 Batch 0 Loss 0.4698
# Epoch 3 Batch 10 Loss 0.4820
# Epoch 3 Batch 20 Loss 0.4308
# Epoch 3 Batch 30 Loss 0.4724
# Epoch 3 Batch 40 Loss 0.4223
# Epoch 3 Batch 50 Loss 0.4877
# Epoch 3 Batch 60 Loss 0.4225
# Epoch 3 Batch 70 Loss 0.5043
# Epoch 3 Batch 80 Loss 0.4290
# Epoch 3 Batch 90 Loss 0.4318
# Epoch 3 Batch 100 Loss 0.4765
# Epoch 3 Batch 110 Loss 0.4317
# Epoch 3 Batch 120 Loss 0.4219
# Epoch 3 Batch 130 Loss 0.4938
# Epoch 3 Batch 140 Loss 0.4743
# Epoch 3 Batch 150 Loss 0.4353
# Epoch 3 Loss 0.4476
# Time taken for 3 epoch 53.12200212478638 sec
#
# Epoch 4 Batch 0 Loss 0.4784
# Epoch 4 Batch 10 Loss 0.4086
# Epoch 4 Batch 20 Loss 0.4143
# Epoch 4 Batch 30 Loss 0.4078
# Epoch 4 Batch 40 Loss 0.4162
# Epoch 4 Batch 50 Loss 0.4515
# Epoch 4 Batch 60 Loss 0.4200
# Epoch 4 Batch 70 Loss 0.4327
# Epoch 4 Batch 80 Loss 0.4344
# Epoch 4 Batch 90 Loss 0.4635
# Epoch 4 Batch 100 Loss 0.4615
# Epoch 4 Batch 110 Loss 0.4323
# Epoch 4 Batch 120 Loss 0.4410
# Epoch 4 Batch 130 Loss 0.4318
# Epoch 4 Batch 140 Loss 0.4560
# Epoch 4 Batch 150 Loss 0.4207
# Epoch 4 Loss 0.4315
# Time taken for 4 epoch 53.53607416152954 sec
#
# Epoch 5 Batch 0 Loss 0.4080
# Epoch 5 Batch 10 Loss 0.4187
# Epoch 5 Batch 20 Loss 0.4240
# Epoch 5 Batch 30 Loss 0.4103
# Epoch 5 Batch 40 Loss 0.4213
# Epoch 5 Batch 50 Loss 0.3894
# Epoch 5 Batch 60 Loss 0.4127
# Epoch 5 Batch 70 Loss 0.3928
# Epoch 5 Batch 80 Loss 0.4062
# Epoch 5 Batch 90 Loss 0.4171
# Epoch 5 Batch 100 Loss 0.4205
# Epoch 5 Batch 110 Loss 0.4322
# Epoch 5 Batch 120 Loss 0.4131
# Epoch 5 Batch 130 Loss 0.4079
# Epoch 5 Batch 140 Loss 0.4171
# Epoch 5 Batch 150 Loss 0.4501
# Epoch 5 Loss 0.4154
# Time taken for 5 epoch 53.488975524902344 sec
#
# Epoch 6 Batch 0 Loss 0.4085
# Epoch 6 Batch 10 Loss 0.3921
# Epoch 6 Batch 20 Loss 0.3996
# Epoch 6 Batch 30 Loss 0.3866
# Epoch 6 Batch 40 Loss 0.3969
# Epoch 6 Batch 50 Loss 0.4007
# Epoch 6 Batch 60 Loss 0.3992
# Epoch 6 Batch 70 Loss 0.3703
# Epoch 6 Batch 80 Loss 0.4067
# Epoch 6 Batch 90 Loss 0.4046
# Epoch 6 Batch 100 Loss 0.4260
# Epoch 6 Batch 110 Loss 0.4308
# Epoch 6 Batch 120 Loss 0.4163
# Epoch 6 Batch 130 Loss 0.3995
# Epoch 6 Batch 140 Loss 0.3677
# Epoch 6 Batch 150 Loss 0.3691
# Epoch 6 Loss 0.3975
# Time taken for 6 epoch 53.51786756515503 sec
#
# Epoch 7 Batch 0 Loss 0.4087
# Epoch 7 Batch 10 Loss 0.3786
# Epoch 7 Batch 20 Loss 0.3662
# Epoch 7 Batch 30 Loss 0.4012
# Epoch 7 Batch 40 Loss 0.3373
# Epoch 7 Batch 50 Loss 0.3987
# Epoch 7 Batch 60 Loss 0.3812
# Epoch 7 Batch 70 Loss 0.3712
# Epoch 7 Batch 80 Loss 0.3457
# Epoch 7 Batch 90 Loss 0.3759
# Epoch 7 Batch 100 Loss 0.3888
# Epoch 7 Batch 110 Loss 0.3607
# Epoch 7 Batch 120 Loss 0.3574
# Epoch 7 Batch 130 Loss 0.3995
# Epoch 7 Batch 140 Loss 0.3669
# Epoch 7 Batch 150 Loss 0.3971
# Epoch 7 Loss 0.3799
# Time taken for 7 epoch 53.55039024353027 sec
#
# Epoch 8 Batch 0 Loss 0.3855
# Epoch 8 Batch 10 Loss 0.3436
# Epoch 8 Batch 20 Loss 0.3420
# Epoch 8 Batch 30 Loss 0.3387
# Epoch 8 Batch 40 Loss 0.3871
# Epoch 8 Batch 50 Loss 0.3520
# Epoch 8 Batch 60 Loss 0.3494
# Epoch 8 Batch 70 Loss 0.3691
# Epoch 8 Batch 80 Loss 0.3823
# Epoch 8 Batch 90 Loss 0.3612
# Epoch 8 Batch 100 Loss 0.3288
# Epoch 8 Batch 110 Loss 0.3640
# Epoch 8 Batch 120 Loss 0.3846
# Epoch 8 Batch 130 Loss 0.3449
# Epoch 8 Batch 140 Loss 0.4027
# Epoch 8 Batch 150 Loss 0.3556
# Epoch 8 Loss 0.3620
# Time taken for 8 epoch 53.53900504112244 sec
#
# Epoch 9 Batch 0 Loss 0.3457
# Epoch 9 Batch 10 Loss 0.3443
# Epoch 9 Batch 20 Loss 0.3327
# Epoch 9 Batch 30 Loss 0.3622
# Epoch 9 Batch 40 Loss 0.3310
# Epoch 9 Batch 50 Loss 0.3710
# Epoch 9 Batch 60 Loss 0.3141
# Epoch 9 Batch 70 Loss 0.3235
# Epoch 9 Batch 80 Loss 0.3834
# Epoch 9 Batch 90 Loss 0.3459
# Epoch 9 Batch 100 Loss 0.3666
# Epoch 9 Batch 110 Loss 0.3682
# Epoch 9 Batch 120 Loss 0.3522
# Epoch 9 Batch 130 Loss 0.3378
# Epoch 9 Batch 140 Loss 0.3568
# Epoch 9 Batch 150 Loss 0.3623
# Epoch 9 Loss 0.3442
# Time taken for 9 epoch 53.49093842506409 sec
#
# Epoch 10 Batch 0 Loss 0.3358
# Epoch 10 Batch 10 Loss 0.3222
# Epoch 10 Batch 20 Loss 0.3167
# Epoch 10 Batch 30 Loss 0.3174
# Epoch 10 Batch 40 Loss 0.2785
# Epoch 10 Batch 50 Loss 0.3162
# Epoch 10 Batch 60 Loss 0.3137
# Epoch 10 Batch 70 Loss 0.3085
# Epoch 10 Batch 80 Loss 0.3440
# Epoch 10 Batch 90 Loss 0.3304
# Epoch 10 Batch 100 Loss 0.3312
# Epoch 10 Batch 110 Loss 0.3483
# Epoch 10 Batch 120 Loss 0.3337
# Epoch 10 Batch 130 Loss 0.3826
# Epoch 10 Batch 140 Loss 0.3374
# Epoch 10 Batch 150 Loss 0.3392
# Epoch 10 Loss 0.3263
# Time taken for 10 epoch 53.54977297782898 sec
#
# Epoch 11 Batch 0 Loss 0.3039
# Epoch 11 Batch 10 Loss 0.3069
# Epoch 11 Batch 20 Loss 0.3105
# Epoch 11 Batch 30 Loss 0.2949
# Epoch 11 Batch 40 Loss 0.3160
# Epoch 11 Batch 50 Loss 0.3073
# Epoch 11 Batch 60 Loss 0.3260
# Epoch 11 Batch 70 Loss 0.3388
# Epoch 11 Batch 80 Loss 0.3195
# Epoch 11 Batch 90 Loss 0.3007
# Epoch 11 Batch 100 Loss 0.3319
# Epoch 11 Batch 110 Loss 0.3253
# Epoch 11 Batch 120 Loss 0.3071
# Epoch 11 Batch 130 Loss 0.3292
# Epoch 11 Batch 140 Loss 0.3275
# Epoch 11 Batch 150 Loss 0.3041
# Epoch 11 Loss 0.3084
# Time taken for 11 epoch 53.528197288513184 sec
#
# Epoch 12 Batch 0 Loss 0.2667
# Epoch 12 Batch 10 Loss 0.2826
# Epoch 12 Batch 20 Loss 0.2890
# Epoch 12 Batch 30 Loss 0.2787
# Epoch 12 Batch 40 Loss 0.2613
# Epoch 12 Batch 50 Loss 0.2989
# Epoch 12 Batch 60 Loss 0.3021
# Epoch 12 Batch 70 Loss 0.3152
# Epoch 12 Batch 80 Loss 0.2971
# Epoch 12 Batch 90 Loss 0.2854
# Epoch 12 Batch 100 Loss 0.3154
# Epoch 12 Batch 110 Loss 0.2692
# Epoch 12 Batch 120 Loss 0.2863
# Epoch 12 Batch 130 Loss 0.2792
# Epoch 12 Batch 140 Loss 0.3072
# Epoch 12 Batch 150 Loss 0.3101
# Epoch 12 Loss 0.2906
# Time taken for 12 epoch 53.53744864463806 sec
#
# Epoch 13 Batch 0 Loss 0.2533
# Epoch 13 Batch 10 Loss 0.2660
# Epoch 13 Batch 20 Loss 0.2635
# Epoch 13 Batch 30 Loss 0.2579
# Epoch 13 Batch 40 Loss 0.2503
# Epoch 13 Batch 50 Loss 0.2904
# Epoch 13 Batch 60 Loss 0.2738
# Epoch 13 Batch 70 Loss 0.2613
# Epoch 13 Batch 80 Loss 0.2792
# Epoch 13 Batch 90 Loss 0.2819
# Epoch 13 Batch 100 Loss 0.2682
# Epoch 13 Batch 110 Loss 0.2735
# Epoch 13 Batch 120 Loss 0.2828
# Epoch 13 Batch 130 Loss 0.2605
# Epoch 13 Batch 140 Loss 0.2418
# Epoch 13 Batch 150 Loss 0.2791
# Epoch 13 Loss 0.2729
# Time taken for 13 epoch 53.49830412864685 sec
#
# Epoch 14 Batch 0 Loss 0.2624
# Epoch 14 Batch 10 Loss 0.2323
# Epoch 14 Batch 20 Loss 0.2332
# Epoch 14 Batch 30 Loss 0.2984
# Epoch 14 Batch 40 Loss 0.2219
# Epoch 14 Batch 50 Loss 0.2730
# Epoch 14 Batch 60 Loss 0.2488
# Epoch 14 Batch 70 Loss 0.2483
# Epoch 14 Batch 80 Loss 0.2315
# Epoch 14 Batch 90 Loss 0.2877
# Epoch 14 Batch 100 Loss 0.2836
# Epoch 14 Batch 110 Loss 0.2676
# Epoch 14 Batch 120 Loss 0.2849
# Epoch 14 Batch 130 Loss 0.2672
# Epoch 14 Batch 140 Loss 0.2609
# Epoch 14 Batch 150 Loss 0.2630
# Epoch 14 Loss 0.2543
# Time taken for 14 epoch 53.535282611846924 sec
#
# Epoch 15 Batch 0 Loss 0.2189
# Epoch 15 Batch 10 Loss 0.2407
# Epoch 15 Batch 20 Loss 0.2093
# Epoch 15 Batch 30 Loss 0.2286
# Epoch 15 Batch 40 Loss 0.2311
# Epoch 15 Batch 50 Loss 0.2429
# Epoch 15 Batch 60 Loss 0.2185
# Epoch 15 Batch 70 Loss 0.2295
# Epoch 15 Batch 80 Loss 0.2387
# Epoch 15 Batch 90 Loss 0.2385
# Epoch 15 Batch 100 Loss 0.2414
# Epoch 15 Batch 110 Loss 0.2253
# Epoch 15 Batch 120 Loss 0.2633
# Epoch 15 Batch 130 Loss 0.2454
# Epoch 15 Batch 140 Loss 0.2506
# Epoch 15 Batch 150 Loss 0.2538
# Epoch 15 Loss 0.2363
# Time taken for 15 epoch 53.5384840965271 sec
#
# Epoch 16 Batch 0 Loss 0.2011
# Epoch 16 Batch 10 Loss 0.1901
# Epoch 16 Batch 20 Loss 0.1924
# Epoch 16 Batch 30 Loss 0.2063
# Epoch 16 Batch 40 Loss 0.2055
# Epoch 16 Batch 50 Loss 0.2261
# Epoch 16 Batch 60 Loss 0.2164
# Epoch 16 Batch 70 Loss 0.2243
# Epoch 16 Batch 80 Loss 0.2253
# Epoch 16 Batch 90 Loss 0.2198
# Epoch 16 Batch 100 Loss 0.2299
# Epoch 16 Batch 110 Loss 0.2123
# Epoch 16 Batch 120 Loss 0.2351
# Epoch 16 Batch 130 Loss 0.2203
# Epoch 16 Batch 140 Loss 0.2181
# Epoch 16 Batch 150 Loss 0.2341
# Epoch 16 Loss 0.2185
# Time taken for 16 epoch 53.53568506240845 sec
#
# Epoch 17 Batch 0 Loss 0.2077
# Epoch 17 Batch 10 Loss 0.1974
# Epoch 17 Batch 20 Loss 0.1771
# Epoch 17 Batch 30 Loss 0.2071
# Epoch 17 Batch 40 Loss 0.1985
# Epoch 17 Batch 50 Loss 0.2048
# Epoch 17 Batch 60 Loss 0.1977
# Epoch 17 Batch 70 Loss 0.1921
# Epoch 17 Batch 80 Loss 0.2012
# Epoch 17 Batch 90 Loss 0.1961
# Epoch 17 Batch 100 Loss 0.1983
# Epoch 17 Batch 110 Loss 0.2024
# Epoch 17 Batch 120 Loss 0.2051
# Epoch 17 Batch 130 Loss 0.2012
# Epoch 17 Batch 140 Loss 0.1983
# Epoch 17 Batch 150 Loss 0.1998
# Epoch 17 Loss 0.2011
# Time taken for 17 epoch 81.91582131385803 sec
#
# Epoch 18 Batch 0 Loss 0.1730
# Epoch 18 Batch 10 Loss 0.1754
# Epoch 18 Batch 20 Loss 0.1706
# Epoch 18 Batch 30 Loss 0.1701
# Epoch 18 Batch 40 Loss 0.1875
# Epoch 18 Batch 50 Loss 0.1817
# Epoch 18 Batch 60 Loss 0.1800
# Epoch 18 Batch 70 Loss 0.1814
# Epoch 18 Batch 80 Loss 0.1904
# Epoch 18 Batch 90 Loss 0.1773
# Epoch 18 Batch 100 Loss 0.1782
# Epoch 18 Batch 110 Loss 0.2119
# Epoch 18 Batch 120 Loss 0.1806
# Epoch 18 Batch 130 Loss 0.1978
# Epoch 18 Batch 140 Loss 0.1851
# Epoch 18 Batch 150 Loss 0.1909
# Epoch 18 Loss 0.1842
# Time taken for 18 epoch 53.89142990112305 sec
#
# Epoch 19 Batch 0 Loss 0.1789
# Epoch 19 Batch 10 Loss 0.1532
# Epoch 19 Batch 20 Loss 0.1581
# Epoch 19 Batch 30 Loss 0.1692
# Epoch 19 Batch 40 Loss 0.1653
# Epoch 19 Batch 50 Loss 0.1817
# Epoch 19 Batch 60 Loss 0.1595
# Epoch 19 Batch 70 Loss 0.1714
# Epoch 19 Batch 80 Loss 0.1624
# Epoch 19 Batch 90 Loss 0.1801
# Epoch 19 Batch 100 Loss 0.1706
# Epoch 19 Batch 110 Loss 0.1777
# Epoch 19 Batch 120 Loss 0.1720
# Epoch 19 Batch 130 Loss 0.1902
# Epoch 19 Batch 140 Loss 0.1811
# Epoch 19 Batch 150 Loss 0.1795
# Epoch 19 Loss 0.1676
# Time taken for 19 epoch 53.36521887779236 sec
#
# Epoch 20 Batch 0 Loss 0.1319
# Epoch 20 Batch 10 Loss 0.1324
# Epoch 20 Batch 20 Loss 0.1424
# Epoch 20 Batch 30 Loss 0.1457
# Epoch 20 Batch 40 Loss 0.1426
# Epoch 20 Batch 50 Loss 0.1594
# Epoch 20 Batch 60 Loss 0.1661
# Epoch 20 Batch 70 Loss 0.1564
# Epoch 20 Batch 80 Loss 0.1471
# Epoch 20 Batch 90 Loss 0.1640
# Epoch 20 Batch 100 Loss 0.1574
# Epoch 20 Batch 110 Loss 0.1590
# Epoch 20 Batch 120 Loss 0.1631
# Epoch 20 Batch 130 Loss 0.1529
# Epoch 20 Batch 140 Loss 0.1673
# Epoch 20 Batch 150 Loss 0.1658
# Epoch 20 Loss 0.1518
# Time taken for 20 epoch 53.60543155670166 sec
#
# Epoch 21 Batch 0 Loss 0.1245
# Epoch 21 Batch 10 Loss 0.1283
# Epoch 21 Batch 20 Loss 0.1357
# Epoch 21 Batch 30 Loss 0.1304
# Epoch 21 Batch 40 Loss 0.1417
# Epoch 21 Batch 50 Loss 0.1491
# Epoch 21 Batch 60 Loss 0.1513
# Epoch 21 Batch 70 Loss 0.1403
# Epoch 21 Batch 80 Loss 0.1534
# Epoch 21 Batch 90 Loss 0.1482
# Epoch 21 Batch 100 Loss 0.1316
# Epoch 21 Batch 110 Loss 0.1482
# Epoch 21 Batch 120 Loss 0.1394
# Epoch 21 Batch 130 Loss 0.1347
# Epoch 21 Batch 140 Loss 0.1570
# Epoch 21 Batch 150 Loss 0.1562
# Epoch 21 Loss 0.1373
# Time taken for 21 epoch 53.526739835739136 sec
#
# Epoch 22 Batch 0 Loss 0.1029
# Epoch 22 Batch 10 Loss 0.1112
# Epoch 22 Batch 20 Loss 0.1035
# Epoch 22 Batch 30 Loss 0.1124
# Epoch 22 Batch 40 Loss 0.1159
# Epoch 22 Batch 50 Loss 0.1203
# Epoch 22 Batch 60 Loss 0.1219
# Epoch 22 Batch 70 Loss 0.1270
# Epoch 22 Batch 80 Loss 0.1088
# Epoch 22 Batch 90 Loss 0.1268
# Epoch 22 Batch 100 Loss 0.1160
# Epoch 22 Batch 110 Loss 0.1412
# Epoch 22 Batch 120 Loss 0.1336
# Epoch 22 Batch 130 Loss 0.1186
# Epoch 22 Batch 140 Loss 0.1249
# Epoch 22 Batch 150 Loss 0.1260
# Epoch 22 Loss 0.1227
# Time taken for 22 epoch 53.55350089073181 sec
#
# Epoch 23 Batch 0 Loss 0.0991
# Epoch 23 Batch 10 Loss 0.1015
# Epoch 23 Batch 20 Loss 0.1098
# Epoch 23 Batch 30 Loss 0.1132
# Epoch 23 Batch 40 Loss 0.1012
# Epoch 23 Batch 50 Loss 0.1103
# Epoch 23 Batch 60 Loss 0.0928
# Epoch 23 Batch 70 Loss 0.1106
# Epoch 23 Batch 80 Loss 0.1192
# Epoch 23 Batch 90 Loss 0.1127
# Epoch 23 Batch 100 Loss 0.1184
# Epoch 23 Batch 110 Loss 0.1198
# Epoch 23 Batch 120 Loss 0.1259
# Epoch 23 Batch 130 Loss 0.1202
# Epoch 23 Batch 140 Loss 0.1315
# Epoch 23 Batch 150 Loss 0.1167
# Epoch 23 Loss 0.1102
# Time taken for 23 epoch 53.5734121799469 sec
#
# Epoch 24 Batch 0 Loss 0.0805
# Epoch 24 Batch 10 Loss 0.0851
# Epoch 24 Batch 20 Loss 0.0968
# Epoch 24 Batch 30 Loss 0.0976
# Epoch 24 Batch 40 Loss 0.1070
# Epoch 24 Batch 50 Loss 0.0978
# Epoch 24 Batch 60 Loss 0.0936
# Epoch 24 Batch 70 Loss 0.1066
# Epoch 24 Batch 80 Loss 0.0909
# Epoch 24 Batch 90 Loss 0.0930
# Epoch 24 Batch 100 Loss 0.0945
# Epoch 24 Batch 110 Loss 0.1013
# Epoch 24 Batch 120 Loss 0.1070
# Epoch 24 Batch 130 Loss 0.1135
# Epoch 24 Batch 140 Loss 0.0957
# Epoch 24 Batch 150 Loss 0.1077
# Epoch 24 Loss 0.0991
# Time taken for 24 epoch 53.5251567363739 sec
#
# Epoch 25 Batch 0 Loss 0.0869
# Epoch 25 Batch 10 Loss 0.0761
# Epoch 25 Batch 20 Loss 0.0749
# Epoch 25 Batch 30 Loss 0.0939
# Epoch 25 Batch 40 Loss 0.0868
# Epoch 25 Batch 50 Loss 0.0823
# Epoch 25 Batch 60 Loss 0.0802
# Epoch 25 Batch 70 Loss 0.0905
# Epoch 25 Batch 80 Loss 0.0939
# Epoch 25 Batch 90 Loss 0.0901
# Epoch 25 Batch 100 Loss 0.0867
# Epoch 25 Batch 110 Loss 0.0877
# Epoch 25 Batch 120 Loss 0.1006
# Epoch 25 Batch 130 Loss 0.0916
# Epoch 25 Batch 140 Loss 0.0858
# Epoch 25 Batch 150 Loss 0.0982
# Epoch 25 Loss 0.0888
# Time taken for 25 epoch 53.54058623313904 sec
#
# Epoch 26 Batch 0 Loss 0.0739
# Epoch 26 Batch 10 Loss 0.0732
# Epoch 26 Batch 20 Loss 0.0807
# Epoch 26 Batch 30 Loss 0.0670
# Epoch 26 Batch 40 Loss 0.0872
# Epoch 26 Batch 50 Loss 0.0730
# Epoch 26 Batch 60 Loss 0.0767
# Epoch 26 Batch 70 Loss 0.0723
# Epoch 26 Batch 80 Loss 0.0914
# Epoch 26 Batch 90 Loss 0.0854
# Epoch 26 Batch 100 Loss 0.0893
# Epoch 26 Batch 110 Loss 0.0753
# Epoch 26 Batch 120 Loss 0.0833
# Epoch 26 Batch 130 Loss 0.0797
# Epoch 26 Batch 140 Loss 0.0840
# Epoch 26 Batch 150 Loss 0.0836
# Epoch 26 Loss 0.0800
# Time taken for 26 epoch 53.56659507751465 sec
#
# Epoch 27 Batch 0 Loss 0.0644
# Epoch 27 Batch 10 Loss 0.0672
# Epoch 27 Batch 20 Loss 0.0685
# Epoch 27 Batch 30 Loss 0.0656
# Epoch 27 Batch 40 Loss 0.0637
# Epoch 27 Batch 50 Loss 0.0664
# Epoch 27 Batch 60 Loss 0.0689
# Epoch 27 Batch 70 Loss 0.0634
# Epoch 27 Batch 80 Loss 0.0783
# Epoch 27 Batch 90 Loss 0.0715
# Epoch 27 Batch 100 Loss 0.0690
# Epoch 27 Batch 110 Loss 0.0759
# Epoch 27 Batch 120 Loss 0.0803
# Epoch 27 Batch 130 Loss 0.0756
# Epoch 27 Batch 140 Loss 0.0686
# Epoch 27 Batch 150 Loss 0.0797
# Epoch 27 Loss 0.0723
# Time taken for 27 epoch 53.58312010765076 sec
#
# Epoch 28 Batch 0 Loss 0.0539
# Epoch 28 Batch 10 Loss 0.0615
# Epoch 28 Batch 20 Loss 0.0595
# Epoch 28 Batch 30 Loss 0.0603
# Epoch 28 Batch 40 Loss 0.0507
# Epoch 28 Batch 50 Loss 0.0653
# Epoch 28 Batch 60 Loss 0.0619
# Epoch 28 Batch 70 Loss 0.0722
# Epoch 28 Batch 80 Loss 0.0791
# Epoch 28 Batch 90 Loss 0.0711
# Epoch 28 Batch 100 Loss 0.0661
# Epoch 28 Batch 110 Loss 0.0684
# Epoch 28 Batch 120 Loss 0.0647
# Epoch 28 Batch 130 Loss 0.0614
# Epoch 28 Batch 140 Loss 0.0728
# Epoch 28 Batch 150 Loss 0.0619
# Epoch 28 Loss 0.0650
# Time taken for 28 epoch 53.582884788513184 sec
#
# Epoch 29 Batch 0 Loss 0.0481
# Epoch 29 Batch 10 Loss 0.0521
# Epoch 29 Batch 20 Loss 0.0542
# Epoch 29 Batch 30 Loss 0.0519
# Epoch 29 Batch 40 Loss 0.0594
# Epoch 29 Batch 50 Loss 0.0600
# Epoch 29 Batch 60 Loss 0.0538
# Epoch 29 Batch 70 Loss 0.0614
# Epoch 29 Batch 80 Loss 0.0579
# Epoch 29 Batch 90 Loss 0.0477
# Epoch 29 Batch 100 Loss 0.0639
# Epoch 29 Batch 110 Loss 0.0602
# Epoch 29 Batch 120 Loss 0.0643
# Epoch 29 Batch 130 Loss 0.0607
# Epoch 29 Batch 140 Loss 0.0658
# Epoch 29 Batch 150 Loss 0.0595
# Epoch 29 Loss 0.0587
# Time taken for 29 epoch 53.58481454849243 sec
#
# Epoch 30 Batch 0 Loss 0.0419
# Epoch 30 Batch 10 Loss 0.0478
# Epoch 30 Batch 20 Loss 0.0497
# Epoch 30 Batch 30 Loss 0.0545
# Epoch 30 Batch 40 Loss 0.0488
# Epoch 30 Batch 50 Loss 0.0482
# Epoch 30 Batch 60 Loss 0.0545
# Epoch 30 Batch 70 Loss 0.0538
# Epoch 30 Batch 80 Loss 0.0578
# Epoch 30 Batch 90 Loss 0.0570
# Epoch 30 Batch 100 Loss 0.0644
# Epoch 30 Batch 110 Loss 0.0546
# Epoch 30 Batch 120 Loss 0.0485
# Epoch 30 Batch 130 Loss 0.0555
# Epoch 30 Batch 140 Loss 0.0638
# Epoch 30 Batch 150 Loss 0.0521
# Epoch 30 Loss 0.0529
# Time taken for 30 epoch 53.54269242286682 sec
#
# Epoch 31 Batch 0 Loss 0.0448
# Epoch 31 Batch 10 Loss 0.0426
# Epoch 31 Batch 20 Loss 0.0359
# Epoch 31 Batch 30 Loss 0.0421
# Epoch 31 Batch 40 Loss 0.0532
# Epoch 31 Batch 50 Loss 0.0391
# Epoch 31 Batch 60 Loss 0.0447
# Epoch 31 Batch 70 Loss 0.0485
# Epoch 31 Batch 80 Loss 0.0486
# Epoch 31 Batch 90 Loss 0.0584
# Epoch 31 Batch 100 Loss 0.0499
# Epoch 31 Batch 110 Loss 0.0572
# Epoch 31 Batch 120 Loss 0.0547
# Epoch 31 Batch 130 Loss 0.0548
# Epoch 31 Batch 140 Loss 0.0510
# Epoch 31 Batch 150 Loss 0.0550
# Epoch 31 Loss 0.0476
# Time taken for 31 epoch 53.52924036979675 sec
#
# Epoch 32 Batch 0 Loss 0.0423
# Epoch 32 Batch 10 Loss 0.0425
# Epoch 32 Batch 20 Loss 0.0342
# Epoch 32 Batch 30 Loss 0.0401
# Epoch 32 Batch 40 Loss 0.0434
# Epoch 32 Batch 50 Loss 0.0407
# Epoch 32 Batch 60 Loss 0.0476
# Epoch 32 Batch 70 Loss 0.0439
# Epoch 32 Batch 80 Loss 0.0412
# Epoch 32 Batch 90 Loss 0.0412
# Epoch 32 Batch 100 Loss 0.0386
# Epoch 32 Batch 110 Loss 0.0410
# Epoch 32 Batch 120 Loss 0.0432
# Epoch 32 Batch 130 Loss 0.0544
# Epoch 32 Batch 140 Loss 0.0485
# Epoch 32 Batch 150 Loss 0.0466
# Epoch 32 Loss 0.0428
# Time taken for 32 epoch 53.52030277252197 sec
#
# Epoch 33 Batch 0 Loss 0.0386
# Epoch 33 Batch 10 Loss 0.0299
# Epoch 33 Batch 20 Loss 0.0329
# Epoch 33 Batch 30 Loss 0.0399
# Epoch 33 Batch 40 Loss 0.0389
# Epoch 33 Batch 50 Loss 0.0347
# Epoch 33 Batch 60 Loss 0.0376
# Epoch 33 Batch 70 Loss 0.0388
# Epoch 33 Batch 80 Loss 0.0393
# Epoch 33 Batch 90 Loss 0.0394
# Epoch 33 Batch 100 Loss 0.0443
# Epoch 33 Batch 110 Loss 0.0409
# Epoch 33 Batch 120 Loss 0.0430
# Epoch 33 Batch 130 Loss 0.0419
# Epoch 33 Batch 140 Loss 0.0429
# Epoch 33 Batch 150 Loss 0.0368
# Epoch 33 Loss 0.0382
# Time taken for 33 epoch 53.56196713447571 sec
#
# Epoch 34 Batch 0 Loss 0.0318
# Epoch 34 Batch 10 Loss 0.0367
# Epoch 34 Batch 20 Loss 0.0291
# Epoch 34 Batch 30 Loss 0.0378
# Epoch 34 Batch 40 Loss 0.0372
# Epoch 34 Batch 50 Loss 0.0327
# Epoch 34 Batch 60 Loss 0.0308
# Epoch 34 Batch 70 Loss 0.0322
# Epoch 34 Batch 80 Loss 0.0340
# Epoch 34 Batch 90 Loss 0.0289
# Epoch 34 Batch 100 Loss 0.0337
# Epoch 34 Batch 110 Loss 0.0357
# Epoch 34 Batch 120 Loss 0.0314
# Epoch 34 Batch 130 Loss 0.0296
# Epoch 34 Batch 140 Loss 0.0330
# Epoch 34 Batch 150 Loss 0.0361
# Epoch 34 Loss 0.0343
# Time taken for 34 epoch 53.55477213859558 sec
#
# Epoch 35 Batch 0 Loss 0.0285
# Epoch 35 Batch 10 Loss 0.0294
# Epoch 35 Batch 20 Loss 0.0246
# Epoch 35 Batch 30 Loss 0.0291
# Epoch 35 Batch 40 Loss 0.0274
# Epoch 35 Batch 50 Loss 0.0295
# Epoch 35 Batch 60 Loss 0.0324
# Epoch 35 Batch 70 Loss 0.0291
# Epoch 35 Batch 80 Loss 0.0350
# Epoch 35 Batch 90 Loss 0.0279
# Epoch 35 Batch 100 Loss 0.0321
# Epoch 35 Batch 110 Loss 0.0372
# Epoch 35 Batch 120 Loss 0.0342
# Epoch 35 Batch 130 Loss 0.0299
# Epoch 35 Batch 140 Loss 0.0362
# Epoch 35 Batch 150 Loss 0.0286
# Epoch 35 Loss 0.0307
# Time taken for 35 epoch 53.54814600944519 sec
#
# Epoch 36 Batch 0 Loss 0.0192
# Epoch 36 Batch 10 Loss 0.0207
# Epoch 36 Batch 20 Loss 0.0263
# Epoch 36 Batch 30 Loss 0.0216
# Epoch 36 Batch 40 Loss 0.0294
# Epoch 36 Batch 50 Loss 0.0251
# Epoch 36 Batch 60 Loss 0.0247
# Epoch 36 Batch 70 Loss 0.0256
# Epoch 36 Batch 80 Loss 0.0239
# Epoch 36 Batch 90 Loss 0.0288
# Epoch 36 Batch 100 Loss 0.0338
# Epoch 36 Batch 110 Loss 0.0285
# Epoch 36 Batch 120 Loss 0.0299
# Epoch 36 Batch 130 Loss 0.0283
# Epoch 36 Batch 140 Loss 0.0316
# Epoch 36 Batch 150 Loss 0.0296
# Epoch 36 Loss 0.0275
# Time taken for 36 epoch 53.53804612159729 sec
#
# Epoch 37 Batch 0 Loss 0.0183
# Epoch 37 Batch 10 Loss 0.0262
# Epoch 37 Batch 20 Loss 0.0193
# Epoch 37 Batch 30 Loss 0.0146
# Epoch 37 Batch 40 Loss 0.0196
# Epoch 37 Batch 50 Loss 0.0232
# Epoch 37 Batch 60 Loss 0.0192
# Epoch 37 Batch 70 Loss 0.0265
# Epoch 37 Batch 80 Loss 0.0243
# Epoch 37 Batch 90 Loss 0.0291
# Epoch 37 Batch 100 Loss 0.0244
# Epoch 37 Batch 110 Loss 0.0238
# Epoch 37 Batch 120 Loss 0.0238
# Epoch 37 Batch 130 Loss 0.0212
# Epoch 37 Batch 140 Loss 0.0279
# Epoch 37 Batch 150 Loss 0.0276
# Epoch 37 Loss 0.0244
# Time taken for 37 epoch 53.521119832992554 sec
#
# Epoch 38 Batch 0 Loss 0.0244
# Epoch 38 Batch 10 Loss 0.0180
# Epoch 38 Batch 20 Loss 0.0196
# Epoch 38 Batch 30 Loss 0.0239
# Epoch 38 Batch 40 Loss 0.0185
# Epoch 38 Batch 50 Loss 0.0207
# Epoch 38 Batch 60 Loss 0.0196
# Epoch 38 Batch 70 Loss 0.0220
# Epoch 38 Batch 80 Loss 0.0209
# Epoch 38 Batch 90 Loss 0.0205
# Epoch 38 Batch 100 Loss 0.0215
# Epoch 38 Batch 110 Loss 0.0228
# Epoch 38 Batch 120 Loss 0.0227
# Epoch 38 Batch 130 Loss 0.0195
# Epoch 38 Batch 140 Loss 0.0243
# Epoch 38 Batch 150 Loss 0.0274
# Epoch 38 Loss 0.0215
# Time taken for 38 epoch 53.54069471359253 sec
#
# Epoch 39 Batch 0 Loss 0.0137
# Epoch 39 Batch 10 Loss 0.0171
# Epoch 39 Batch 20 Loss 0.0195
# Epoch 39 Batch 30 Loss 0.0168
# Epoch 39 Batch 40 Loss 0.0229
# Epoch 39 Batch 50 Loss 0.0173
# Epoch 39 Batch 60 Loss 0.0183
# Epoch 39 Batch 70 Loss 0.0179
# Epoch 39 Batch 80 Loss 0.0203
# Epoch 39 Batch 90 Loss 0.0212
# Epoch 39 Batch 100 Loss 0.0199
# Epoch 39 Batch 110 Loss 0.0221
# Epoch 39 Batch 120 Loss 0.0192
# Epoch 39 Batch 130 Loss 0.0212
# Epoch 39 Batch 140 Loss 0.0232
# Epoch 39 Batch 150 Loss 0.0198
# Epoch 39 Loss 0.0191
# Time taken for 39 epoch 53.53188633918762 sec
#
# Epoch 40 Batch 0 Loss 0.0137
# Epoch 40 Batch 10 Loss 0.0125
# Epoch 40 Batch 20 Loss 0.0155
# Epoch 40 Batch 30 Loss 0.0131
# Epoch 40 Batch 40 Loss 0.0169
# Epoch 40 Batch 50 Loss 0.0172
# Epoch 40 Batch 60 Loss 0.0210
# Epoch 40 Batch 70 Loss 0.0168
# Epoch 40 Batch 80 Loss 0.0167
# Epoch 40 Batch 90 Loss 0.0181
# Epoch 40 Batch 100 Loss 0.0158
# Epoch 40 Batch 110 Loss 0.0167
# Epoch 40 Batch 120 Loss 0.0179
# Epoch 40 Batch 130 Loss 0.0158
# Epoch 40 Batch 140 Loss 0.0197
# Epoch 40 Batch 150 Loss 0.0149
# Epoch 40 Loss 0.0168
# Time taken for 40 epoch 53.52375602722168 sec
#
# Epoch 41 Batch 0 Loss 0.0120
# Epoch 41 Batch 10 Loss 0.0107
# Epoch 41 Batch 20 Loss 0.0151
# Epoch 41 Batch 30 Loss 0.0126
# Epoch 41 Batch 40 Loss 0.0138
# Epoch 41 Batch 50 Loss 0.0152
# Epoch 41 Batch 60 Loss 0.0158
# Epoch 41 Batch 70 Loss 0.0131
# Epoch 41 Batch 80 Loss 0.0093
# Epoch 41 Batch 90 Loss 0.0140
# Epoch 41 Batch 100 Loss 0.0189
# Epoch 41 Batch 110 Loss 0.0172
# Epoch 41 Batch 120 Loss 0.0158
# Epoch 41 Batch 130 Loss 0.0191
# Epoch 41 Batch 140 Loss 0.0166
# Epoch 41 Batch 150 Loss 0.0187
# Epoch 41 Loss 0.0148
# Time taken for 41 epoch 53.517107248306274 sec
#
# Epoch 42 Batch 0 Loss 0.0106
# Epoch 42 Batch 10 Loss 0.0095
# Epoch 42 Batch 20 Loss 0.0113
# Epoch 42 Batch 30 Loss 0.0124
# Epoch 42 Batch 40 Loss 0.0122
# Epoch 42 Batch 50 Loss 0.0114
# Epoch 42 Batch 60 Loss 0.0135
# Epoch 42 Batch 70 Loss 0.0134
# Epoch 42 Batch 80 Loss 0.0128
# Epoch 42 Batch 90 Loss 0.0149
# Epoch 42 Batch 100 Loss 0.0148
# Epoch 42 Batch 110 Loss 0.0094
# Epoch 42 Batch 120 Loss 0.0167
# Epoch 42 Batch 130 Loss 0.0150
# Epoch 42 Batch 140 Loss 0.0151
# Epoch 42 Batch 150 Loss 0.0158
# Epoch 42 Loss 0.0131
# Time taken for 42 epoch 53.54106783866882 sec
#
# Epoch 43 Batch 0 Loss 0.0069
# Epoch 43 Batch 10 Loss 0.0107
# Epoch 43 Batch 20 Loss 0.0089
# Epoch 43 Batch 30 Loss 0.0102
# Epoch 43 Batch 40 Loss 0.0114
# Epoch 43 Batch 50 Loss 0.0122
# Epoch 43 Batch 60 Loss 0.0118
# Epoch 43 Batch 70 Loss 0.0114
# Epoch 43 Batch 80 Loss 0.0110
# Epoch 43 Batch 90 Loss 0.0129
# Epoch 43 Batch 100 Loss 0.0128
# Epoch 43 Batch 110 Loss 0.0102
# Epoch 43 Batch 120 Loss 0.0131
# Epoch 43 Batch 130 Loss 0.0115
# Epoch 43 Batch 140 Loss 0.0134
# Epoch 43 Batch 150 Loss 0.0150
# Epoch 43 Loss 0.0119
# Time taken for 43 epoch 55.036112546920776 sec
#
# Epoch 44 Batch 0 Loss 0.0130
# Epoch 44 Batch 10 Loss 0.0083
# Epoch 44 Batch 20 Loss 0.0091
# Epoch 44 Batch 30 Loss 0.0087
# Epoch 44 Batch 40 Loss 0.0080
# Epoch 44 Batch 50 Loss 0.0090
# Epoch 44 Batch 60 Loss 0.0132
# Epoch 44 Batch 70 Loss 0.0121
# Epoch 44 Batch 80 Loss 0.0107
# Epoch 44 Batch 90 Loss 0.0093
# Epoch 44 Batch 100 Loss 0.0081
# Epoch 44 Batch 110 Loss 0.0089
# Epoch 44 Batch 120 Loss 0.0114
# Epoch 44 Batch 130 Loss 0.0096
# Epoch 44 Batch 140 Loss 0.0123
# Epoch 44 Batch 150 Loss 0.0113
# Epoch 44 Loss 0.0109
# Time taken for 44 epoch 53.53982615470886 sec
#
# Epoch 45 Batch 0 Loss 0.0090
# Epoch 45 Batch 10 Loss 0.0103
# Epoch 45 Batch 20 Loss 0.0094
# Epoch 45 Batch 30 Loss 0.0081
# Epoch 45 Batch 40 Loss 0.0082
# Epoch 45 Batch 50 Loss 0.0083
# Epoch 45 Batch 60 Loss 0.0109
# Epoch 45 Batch 70 Loss 0.0092
# Epoch 45 Batch 80 Loss 0.0102
# Epoch 45 Batch 90 Loss 0.0093
# Epoch 45 Batch 100 Loss 0.0091
# Epoch 45 Batch 110 Loss 0.0073
# Epoch 45 Batch 120 Loss 0.0088
# Epoch 45 Batch 130 Loss 0.0102
# Epoch 45 Batch 140 Loss 0.0081
# Epoch 45 Batch 150 Loss 0.0104
# Epoch 45 Loss 0.0095
# Time taken for 45 epoch 53.615559101104736 sec
#
# Epoch 46 Batch 0 Loss 0.0094
# Epoch 46 Batch 10 Loss 0.0078
# Epoch 46 Batch 20 Loss 0.0081
# Epoch 46 Batch 30 Loss 0.0063
# Epoch 46 Batch 40 Loss 0.0068
# Epoch 46 Batch 50 Loss 0.0075
# Epoch 46 Batch 60 Loss 0.0053
# Epoch 46 Batch 70 Loss 0.0076
# Epoch 46 Batch 80 Loss 0.0085
# Epoch 46 Batch 90 Loss 0.0085
# Epoch 46 Batch 100 Loss 0.0088
# Epoch 46 Batch 110 Loss 0.0085
# Epoch 46 Batch 120 Loss 0.0103
# Epoch 46 Batch 130 Loss 0.0080
# Epoch 46 Batch 140 Loss 0.0112
# Epoch 46 Batch 150 Loss 0.0113
# Epoch 46 Loss 0.0084
# Time taken for 46 epoch 53.529494524002075 sec
#
# Epoch 47 Batch 0 Loss 0.0049
# Epoch 47 Batch 10 Loss 0.0060
# Epoch 47 Batch 20 Loss 0.0062
# Epoch 47 Batch 30 Loss 0.0065
# Epoch 47 Batch 40 Loss 0.0091
# Epoch 47 Batch 50 Loss 0.0106
# Epoch 47 Batch 60 Loss 0.0080
# Epoch 47 Batch 70 Loss 0.0085
# Epoch 47 Batch 80 Loss 0.0070
# Epoch 47 Batch 90 Loss 0.0092
# Epoch 47 Batch 100 Loss 0.0063
# Epoch 47 Batch 110 Loss 0.0074
# Epoch 47 Batch 120 Loss 0.0098
# Epoch 47 Batch 130 Loss 0.0063
# Epoch 47 Batch 140 Loss 0.0104
# Epoch 47 Batch 150 Loss 0.0086
# Epoch 47 Loss 0.0075
# Time taken for 47 epoch 53.57687020301819 sec
#
# Epoch 48 Batch 0 Loss 0.0058
# Epoch 48 Batch 10 Loss 0.0049
# Epoch 48 Batch 20 Loss 0.0070
# Epoch 48 Batch 30 Loss 0.0055
# Epoch 48 Batch 40 Loss 0.0066
# Epoch 48 Batch 50 Loss 0.0073
# Epoch 48 Batch 60 Loss 0.0045
# Epoch 48 Batch 70 Loss 0.0052
# Epoch 48 Batch 80 Loss 0.0080
# Epoch 48 Batch 90 Loss 0.0079
# Epoch 48 Batch 100 Loss 0.0098
# Epoch 48 Batch 110 Loss 0.0061
# Epoch 48 Batch 120 Loss 0.0091
# Epoch 48 Batch 130 Loss 0.0056
# Epoch 48 Batch 140 Loss 0.0077
# Epoch 48 Batch 150 Loss 0.0062
# Epoch 48 Loss 0.0068
# Time taken for 48 epoch 53.545974254608154 sec
#
# Epoch 49 Batch 0 Loss 0.0038
# Epoch 49 Batch 10 Loss 0.0059
# Epoch 49 Batch 20 Loss 0.0057
# Epoch 49 Batch 30 Loss 0.0054
# Epoch 49 Batch 40 Loss 0.0048
# Epoch 49 Batch 50 Loss 0.0056
# Epoch 49 Batch 60 Loss 0.0068
# Epoch 49 Batch 70 Loss 0.0054
# Epoch 49 Batch 80 Loss 0.0061
# Epoch 49 Batch 90 Loss 0.0055
# Epoch 49 Batch 100 Loss 0.0050
# Epoch 49 Batch 110 Loss 0.0057
# Epoch 49 Batch 120 Loss 0.0045
# Epoch 49 Batch 130 Loss 0.0059
# Epoch 49 Batch 140 Loss 0.0059
# Epoch 49 Batch 150 Loss 0.0041
# Epoch 49 Loss 0.0059
# Time taken for 49 epoch 53.59099292755127 sec
#
# Epoch 50 Batch 0 Loss 0.0049
# Epoch 50 Batch 10 Loss 0.0067
# Epoch 50 Batch 20 Loss 0.0035
# Epoch 50 Batch 30 Loss 0.0049
# Epoch 50 Batch 40 Loss 0.0052
# Epoch 50 Batch 50 Loss 0.0055
# Epoch 50 Batch 60 Loss 0.0056
# Epoch 50 Batch 70 Loss 0.0050
# Epoch 50 Batch 80 Loss 0.0051
# Epoch 50 Batch 90 Loss 0.0066
# Epoch 50 Batch 100 Loss 0.0047
# Epoch 50 Batch 110 Loss 0.0057
# Epoch 50 Batch 120 Loss 0.0048
# Epoch 50 Batch 130 Loss 0.0047
# Epoch 50 Batch 140 Loss 0.0049
# Epoch 50 Batch 150 Loss 0.0058
# Epoch 50 Loss 0.0051
# Time taken for 50 epoch 57.16782093048096 sec
#
# Epoch 51 Batch 0 Loss 0.0048
# Epoch 51 Batch 10 Loss 0.0035
# Epoch 51 Batch 20 Loss 0.0036
# Epoch 51 Batch 30 Loss 0.0041
# Epoch 51 Batch 40 Loss 0.0054
# Epoch 51 Batch 50 Loss 0.0031
# Epoch 51 Batch 60 Loss 0.0041
# Epoch 51 Batch 70 Loss 0.0057
# Epoch 51 Batch 80 Loss 0.0041
# Epoch 51 Batch 90 Loss 0.0043
# Epoch 51 Batch 100 Loss 0.0053
# Epoch 51 Batch 110 Loss 0.0065
# Epoch 51 Batch 120 Loss 0.0050
# Epoch 51 Batch 130 Loss 0.0069
# Epoch 51 Batch 140 Loss 0.0056
# Epoch 51 Batch 150 Loss 0.0052
# Epoch 51 Loss 0.0048
# Time taken for 51 epoch 53.636141538619995 sec
#
# Epoch 52 Batch 0 Loss 0.0035
# Epoch 52 Batch 10 Loss 0.0040
# Epoch 52 Batch 20 Loss 0.0037
# Epoch 52 Batch 30 Loss 0.0046
# Epoch 52 Batch 40 Loss 0.0056
# Epoch 52 Batch 50 Loss 0.0049
# Epoch 52 Batch 60 Loss 0.0065
# Epoch 52 Batch 70 Loss 0.0053
# Epoch 52 Batch 80 Loss 0.0061
# Epoch 52 Batch 90 Loss 0.0084
# Epoch 52 Batch 100 Loss 0.0051
# Epoch 52 Batch 110 Loss 0.0048
# Epoch 52 Batch 120 Loss 0.0060
# Epoch 52 Batch 130 Loss 0.0051
# Epoch 52 Batch 140 Loss 0.0053
# Epoch 52 Batch 150 Loss 0.0066
# Epoch 52 Loss 0.0054
# Time taken for 52 epoch 53.51767420768738 sec
#
# Epoch 53 Batch 0 Loss 0.0040
# Epoch 53 Batch 10 Loss 0.0062
# Epoch 53 Batch 20 Loss 0.0046
# Epoch 53 Batch 30 Loss 0.0053
# Epoch 53 Batch 40 Loss 0.0061
# Epoch 53 Batch 50 Loss 0.0052
# Epoch 53 Batch 60 Loss 0.0047
# Epoch 53 Batch 70 Loss 0.0041
# Epoch 53 Batch 80 Loss 0.0076
# Epoch 53 Batch 90 Loss 0.0059
# Epoch 53 Batch 100 Loss 0.0054
# Epoch 53 Batch 110 Loss 0.0050
# Epoch 53 Batch 120 Loss 0.0080
# Epoch 53 Batch 130 Loss 0.0067
# Epoch 53 Batch 140 Loss 0.0088
# Epoch 53 Batch 150 Loss 0.0071
# Epoch 53 Loss 0.0057
# Time taken for 53 epoch 53.56619048118591 sec
#
# Epoch 54 Batch 0 Loss 0.0040
# Epoch 54 Batch 10 Loss 0.0039
# Epoch 54 Batch 20 Loss 0.0067
# Epoch 54 Batch 30 Loss 0.0041
# Epoch 54 Batch 40 Loss 0.0060
# Epoch 54 Batch 50 Loss 0.0055
# Epoch 54 Batch 60 Loss 0.0055
# Epoch 54 Batch 70 Loss 0.0037
# Epoch 54 Batch 80 Loss 0.0052
# Epoch 54 Batch 90 Loss 0.0059
# Epoch 54 Batch 100 Loss 0.0047
# Epoch 54 Batch 110 Loss 0.0065
# Epoch 54 Batch 120 Loss 0.0042
# Epoch 54 Batch 130 Loss 0.0053
# Epoch 54 Batch 140 Loss 0.0059
# Epoch 54 Batch 150 Loss 0.0057
# Epoch 54 Loss 0.0052
# Time taken for 54 epoch 53.59331798553467 sec
#
# Epoch 55 Batch 0 Loss 0.0034
# Epoch 55 Batch 10 Loss 0.0051
# Epoch 55 Batch 20 Loss 0.0034
# Epoch 55 Batch 30 Loss 0.0051
# Epoch 55 Batch 40 Loss 0.0038
# Epoch 55 Batch 50 Loss 0.0040
# Epoch 55 Batch 60 Loss 0.0037
# Epoch 55 Batch 70 Loss 0.0052
# Epoch 55 Batch 80 Loss 0.0034
# Epoch 55 Batch 90 Loss 0.0030
# Epoch 55 Batch 100 Loss 0.0051
# Epoch 55 Batch 110 Loss 0.0031
# Epoch 55 Batch 120 Loss 0.0047
# Epoch 55 Batch 130 Loss 0.0044
# Epoch 55 Batch 140 Loss 0.0044
# Epoch 55 Batch 150 Loss 0.0049
# Epoch 55 Loss 0.0040
# Time taken for 55 epoch 53.54749894142151 sec
#
# Epoch 56 Batch 0 Loss 0.0028
# Epoch 56 Batch 10 Loss 0.0038
# Epoch 56 Batch 20 Loss 0.0030
# Epoch 56 Batch 30 Loss 0.0029
# Epoch 56 Batch 40 Loss 0.0034
# Epoch 56 Batch 50 Loss 0.0033
# Epoch 56 Batch 60 Loss 0.0024
# Epoch 56 Batch 70 Loss 0.0035
# Epoch 56 Batch 80 Loss 0.0041
# Epoch 56 Batch 90 Loss 0.0049
# Epoch 56 Batch 100 Loss 0.0026
# Epoch 56 Batch 110 Loss 0.0034
# Epoch 56 Batch 120 Loss 0.0039
# Epoch 56 Batch 130 Loss 0.0035
# Epoch 56 Batch 140 Loss 0.0020
# Epoch 56 Batch 150 Loss 0.0024
# Epoch 56 Loss 0.0032
# Time taken for 56 epoch 53.526755571365356 sec
#
# Epoch 57 Batch 0 Loss 0.0031
# Epoch 57 Batch 10 Loss 0.0026
# Epoch 57 Batch 20 Loss 0.0019
# Epoch 57 Batch 30 Loss 0.0020
# Epoch 57 Batch 40 Loss 0.0030
# Epoch 57 Batch 50 Loss 0.0021
# Epoch 57 Batch 60 Loss 0.0023
# Epoch 57 Batch 70 Loss 0.0021
# Epoch 57 Batch 80 Loss 0.0024
# Epoch 57 Batch 90 Loss 0.0016
# Epoch 57 Batch 100 Loss 0.0026
# Epoch 57 Batch 110 Loss 0.0021
# Epoch 57 Batch 120 Loss 0.0031
# Epoch 57 Batch 130 Loss 0.0034
# Epoch 57 Batch 140 Loss 0.0028
# Epoch 57 Batch 150 Loss 0.0028
# Epoch 57 Loss 0.0026
# Time taken for 57 epoch 53.56023931503296 sec
#
# Epoch 58 Batch 0 Loss 0.0013
# Epoch 58 Batch 10 Loss 0.0028
# Epoch 58 Batch 20 Loss 0.0016
# Epoch 58 Batch 30 Loss 0.0020
# Epoch 58 Batch 40 Loss 0.0024
# Epoch 58 Batch 50 Loss 0.0020
# Epoch 58 Batch 60 Loss 0.0017
# Epoch 58 Batch 70 Loss 0.0023
# Epoch 58 Batch 80 Loss 0.0019
# Epoch 58 Batch 90 Loss 0.0024
# Epoch 58 Batch 100 Loss 0.0025
# Epoch 58 Batch 110 Loss 0.0023
# Epoch 58 Batch 120 Loss 0.0019
# Epoch 58 Batch 130 Loss 0.0025
# Epoch 58 Batch 140 Loss 0.0027
# Epoch 58 Batch 150 Loss 0.0019
# Epoch 58 Loss 0.0023
# Time taken for 58 epoch 53.53488540649414 sec
#
# Epoch 59 Batch 0 Loss 0.0019
# Epoch 59 Batch 10 Loss 0.0019
# Epoch 59 Batch 20 Loss 0.0017
# Epoch 59 Batch 30 Loss 0.0013
# Epoch 59 Batch 40 Loss 0.0012
# Epoch 59 Batch 50 Loss 0.0020
# Epoch 59 Batch 60 Loss 0.0022
# Epoch 59 Batch 70 Loss 0.0016
# Epoch 59 Batch 80 Loss 0.0024
# Epoch 59 Batch 90 Loss 0.0019
# Epoch 59 Batch 100 Loss 0.0019
# Epoch 59 Batch 110 Loss 0.0021
# Epoch 59 Batch 120 Loss 0.0015
# Epoch 59 Batch 130 Loss 0.0023
# Epoch 59 Batch 140 Loss 0.0018
# Epoch 59 Batch 150 Loss 0.0021
# Epoch 59 Loss 0.0018
# Time taken for 59 epoch 53.5257511138916 sec
#
# Epoch 60 Batch 0 Loss 0.0012
# Epoch 60 Batch 10 Loss 0.0014
# Epoch 60 Batch 20 Loss 0.0018
# Epoch 60 Batch 30 Loss 0.0013
# Epoch 60 Batch 40 Loss 0.0013
# Epoch 60 Batch 50 Loss 0.0012
# Epoch 60 Batch 60 Loss 0.0021
# Epoch 60 Batch 70 Loss 0.0013
# Epoch 60 Batch 80 Loss 0.0014
# Epoch 60 Batch 90 Loss 0.0016
# Epoch 60 Batch 100 Loss 0.0012
# Epoch 60 Batch 110 Loss 0.0017
# Epoch 60 Batch 120 Loss 0.0013
# Epoch 60 Batch 130 Loss 0.0013
# Epoch 60 Batch 140 Loss 0.0016
# Epoch 60 Batch 150 Loss 0.0014
# Epoch 60 Loss 0.0015
# Time taken for 60 epoch 53.53979539871216 sec
#
# Epoch 61 Batch 0 Loss 0.0010
# Epoch 61 Batch 10 Loss 0.0012
# Epoch 61 Batch 20 Loss 0.0008
# Epoch 61 Batch 30 Loss 0.0011
# Epoch 61 Batch 40 Loss 0.0009
# Epoch 61 Batch 50 Loss 0.0016
# Epoch 61 Batch 60 Loss 0.0014
# Epoch 61 Batch 70 Loss 0.0012
# Epoch 61 Batch 80 Loss 0.0010
# Epoch 61 Batch 90 Loss 0.0015
# Epoch 61 Batch 100 Loss 0.0012
# Epoch 61 Batch 110 Loss 0.0010
# Epoch 61 Batch 120 Loss 0.0011
# Epoch 61 Batch 130 Loss 0.0014
# Epoch 61 Batch 140 Loss 0.0011
# Epoch 61 Batch 150 Loss 0.0017
# Epoch 61 Loss 0.0012
# Time taken for 61 epoch 53.533275842666626 sec
#
# Epoch 62 Batch 0 Loss 0.0009
# Epoch 62 Batch 10 Loss 0.0009
# Epoch 62 Batch 20 Loss 0.0013
# Epoch 62 Batch 30 Loss 0.0014
# Epoch 62 Batch 40 Loss 0.0011
# Epoch 62 Batch 50 Loss 0.0010
# Epoch 62 Batch 60 Loss 0.0009
# Epoch 62 Batch 70 Loss 0.0008
# Epoch 62 Batch 80 Loss 0.0010
# Epoch 62 Batch 90 Loss 0.0011
# Epoch 62 Batch 100 Loss 0.0009
# Epoch 62 Batch 110 Loss 0.0011
# Epoch 62 Batch 120 Loss 0.0010
# Epoch 62 Batch 130 Loss 0.0007
# Epoch 62 Batch 140 Loss 0.0009
# Epoch 62 Batch 150 Loss 0.0011
# Epoch 62 Loss 0.0011
# Time taken for 62 epoch 53.56489419937134 sec
#
# Epoch 63 Batch 0 Loss 0.0008
# Epoch 63 Batch 10 Loss 0.0015
# Epoch 63 Batch 20 Loss 0.0007
# Epoch 63 Batch 30 Loss 0.0008
# Epoch 63 Batch 40 Loss 0.0012
# Epoch 63 Batch 50 Loss 0.0009
# Epoch 63 Batch 60 Loss 0.0013
# Epoch 63 Batch 70 Loss 0.0011
# Epoch 63 Batch 80 Loss 0.0012
# Epoch 63 Batch 90 Loss 0.0013
# Epoch 63 Batch 100 Loss 0.0009
# Epoch 63 Batch 110 Loss 0.0009
# Epoch 63 Batch 120 Loss 0.0007
# Epoch 63 Batch 130 Loss 0.0008
# Epoch 63 Batch 140 Loss 0.0014
# Epoch 63 Batch 150 Loss 0.0011
# Epoch 63 Loss 0.0009
# Time taken for 63 epoch 53.56926608085632 sec
#
# Epoch 64 Batch 0 Loss 0.0008
# Epoch 64 Batch 10 Loss 0.0009
# Epoch 64 Batch 20 Loss 0.0007
# Epoch 64 Batch 30 Loss 0.0006
# Epoch 64 Batch 40 Loss 0.0008
# Epoch 64 Batch 50 Loss 0.0007
# Epoch 64 Batch 60 Loss 0.0008
# Epoch 64 Batch 70 Loss 0.0010
# Epoch 64 Batch 80 Loss 0.0007
# Epoch 64 Batch 90 Loss 0.0009
# Epoch 64 Batch 100 Loss 0.0009
# Epoch 64 Batch 110 Loss 0.0011
# Epoch 64 Batch 120 Loss 0.0009
# Epoch 64 Batch 130 Loss 0.0008
# Epoch 64 Batch 140 Loss 0.0008
# Epoch 64 Batch 150 Loss 0.0009
# Epoch 64 Loss 0.0008
# Time taken for 64 epoch 53.547837257385254 sec
#
# Epoch 65 Batch 0 Loss 0.0006
# Epoch 65 Batch 10 Loss 0.0008
# Epoch 65 Batch 20 Loss 0.0006
# Epoch 65 Batch 30 Loss 0.0007
# Epoch 65 Batch 40 Loss 0.0008
# Epoch 65 Batch 50 Loss 0.0007
# Epoch 65 Batch 60 Loss 0.0007
# Epoch 65 Batch 70 Loss 0.0007
# Epoch 65 Batch 80 Loss 0.0009
# Epoch 65 Batch 90 Loss 0.0008
# Epoch 65 Batch 100 Loss 0.0009
# Epoch 65 Batch 110 Loss 0.0009
# Epoch 65 Batch 120 Loss 0.0007
# Epoch 65 Batch 130 Loss 0.0006
# Epoch 65 Batch 140 Loss 0.0008
# Epoch 65 Batch 150 Loss 0.0010
# Epoch 65 Loss 0.0008
# Time taken for 65 epoch 53.557026386260986 sec
#
# Epoch 66 Batch 0 Loss 0.0006
# Epoch 66 Batch 10 Loss 0.0005
# Epoch 66 Batch 20 Loss 0.0007
# Epoch 66 Batch 30 Loss 0.0006
# Epoch 66 Batch 40 Loss 0.0006
# Epoch 66 Batch 50 Loss 0.0007
# Epoch 66 Batch 60 Loss 0.0005
# Epoch 66 Batch 70 Loss 0.0006
# Epoch 66 Batch 80 Loss 0.0006
# Epoch 66 Batch 90 Loss 0.0007
# Epoch 66 Batch 100 Loss 0.0007
# Epoch 66 Batch 110 Loss 0.0006
# Epoch 66 Batch 120 Loss 0.0008
# Epoch 66 Batch 130 Loss 0.0011
# Epoch 66 Batch 140 Loss 0.0005
# Epoch 66 Batch 150 Loss 0.0005
# Epoch 66 Loss 0.0007
# Time taken for 66 epoch 53.58896613121033 sec
#
# Epoch 67 Batch 0 Loss 0.0005
# Epoch 67 Batch 10 Loss 0.0005
# Epoch 67 Batch 20 Loss 0.0006
# Epoch 67 Batch 30 Loss 0.0006
# Epoch 67 Batch 40 Loss 0.0005
# Epoch 67 Batch 50 Loss 0.0005
# Epoch 67 Batch 60 Loss 0.0006
# Epoch 67 Batch 70 Loss 0.0006
# Epoch 67 Batch 80 Loss 0.0005
# Epoch 67 Batch 90 Loss 0.0007
# Epoch 67 Batch 100 Loss 0.0006
# Epoch 67 Batch 110 Loss 0.0007
# Epoch 67 Batch 120 Loss 0.0005
# Epoch 67 Batch 130 Loss 0.0006
# Epoch 67 Batch 140 Loss 0.0008
# Epoch 67 Batch 150 Loss 0.0006
# Epoch 67 Loss 0.0007
# Time taken for 67 epoch 53.53316330909729 sec
#
# Epoch 68 Batch 0 Loss 0.0004
# Epoch 68 Batch 10 Loss 0.0005
# Epoch 68 Batch 20 Loss 0.0011
# Epoch 68 Batch 30 Loss 0.0004
# Epoch 68 Batch 40 Loss 0.0007
# Epoch 68 Batch 50 Loss 0.0006
# Epoch 68 Batch 60 Loss 0.0007
# Epoch 68 Batch 70 Loss 0.0006
# Epoch 68 Batch 80 Loss 0.0007
# Epoch 68 Batch 90 Loss 0.0005
# Epoch 68 Batch 100 Loss 0.0006
# Epoch 68 Batch 110 Loss 0.0006
# Epoch 68 Batch 120 Loss 0.0008
# Epoch 68 Batch 130 Loss 0.0007
# Epoch 68 Batch 140 Loss 0.0005
# Epoch 68 Batch 150 Loss 0.0009
# Epoch 68 Loss 0.0006
# Time taken for 68 epoch 53.503010272979736 sec
#
# Epoch 69 Batch 0 Loss 0.0005
# Epoch 69 Batch 10 Loss 0.0005
# Epoch 69 Batch 20 Loss 0.0005
# Epoch 69 Batch 30 Loss 0.0007
# Epoch 69 Batch 40 Loss 0.0006
# Epoch 69 Batch 50 Loss 0.0004
# Epoch 69 Batch 60 Loss 0.0006
# Epoch 69 Batch 70 Loss 0.0005
# Epoch 69 Batch 80 Loss 0.0006
# Epoch 69 Batch 90 Loss 0.0005
# Epoch 69 Batch 100 Loss 0.0006
# Epoch 69 Batch 110 Loss 0.0007
# Epoch 69 Batch 120 Loss 0.0006
# Epoch 69 Batch 130 Loss 0.0004
# Epoch 69 Batch 140 Loss 0.0005
# Epoch 69 Batch 150 Loss 0.0005
# Epoch 69 Loss 0.0006
# Time taken for 69 epoch 53.572746992111206 sec
#
# Epoch 70 Batch 0 Loss 0.0005
# Epoch 70 Batch 10 Loss 0.0004
# Epoch 70 Batch 20 Loss 0.0004
# Epoch 70 Batch 30 Loss 0.0005
# Epoch 70 Batch 40 Loss 0.0007
# Epoch 70 Batch 50 Loss 0.0007
# Epoch 70 Batch 60 Loss 0.0005
# Epoch 70 Batch 70 Loss 0.0004
# Epoch 70 Batch 80 Loss 0.0006
# Epoch 70 Batch 90 Loss 0.0005
# Epoch 70 Batch 100 Loss 0.0005
# Epoch 70 Batch 110 Loss 0.0004
# Epoch 70 Batch 120 Loss 0.0004
# Epoch 70 Batch 130 Loss 0.0005
# Epoch 70 Batch 140 Loss 0.0005
# Epoch 70 Batch 150 Loss 0.0006
# Epoch 70 Loss 0.0006
# Time taken for 70 epoch 53.4980525970459 sec
#
# Epoch 71 Batch 0 Loss 0.0003
# Epoch 71 Batch 10 Loss 0.0004
# Epoch 71 Batch 20 Loss 0.0004
# Epoch 71 Batch 30 Loss 0.0004
# Epoch 71 Batch 40 Loss 0.0004
# Epoch 71 Batch 50 Loss 0.0006
# Epoch 71 Batch 60 Loss 0.0005
# Epoch 71 Batch 70 Loss 0.0004
# Epoch 71 Batch 80 Loss 0.0006
# Epoch 71 Batch 90 Loss 0.0009
# Epoch 71 Batch 100 Loss 0.0005
# Epoch 71 Batch 110 Loss 0.0006
# Epoch 71 Batch 120 Loss 0.0006
# Epoch 71 Batch 130 Loss 0.0010
# Epoch 71 Batch 140 Loss 0.0009
# Epoch 71 Batch 150 Loss 0.0015
# Epoch 71 Loss 0.0006
# Time taken for 71 epoch 53.564817905426025 sec
#
# Epoch 72 Batch 0 Loss 0.0008
# Epoch 72 Batch 10 Loss 0.0011
# Epoch 72 Batch 20 Loss 0.0011
# Epoch 72 Batch 30 Loss 0.0029
# Epoch 72 Batch 40 Loss 0.0044
# Epoch 72 Batch 50 Loss 0.0082
# Epoch 72 Batch 60 Loss 0.0091
# Epoch 72 Batch 70 Loss 0.0089
# Epoch 72 Batch 80 Loss 0.0114
# Epoch 72 Batch 90 Loss 0.0135
# Epoch 72 Batch 100 Loss 0.0139
# Epoch 72 Batch 110 Loss 0.0151
# Epoch 72 Batch 120 Loss 0.0145
# Epoch 72 Batch 130 Loss 0.0191
# Epoch 72 Batch 140 Loss 0.0185
# Epoch 72 Batch 150 Loss 0.0169
# Epoch 72 Loss 0.0102
# Time taken for 72 epoch 53.53119158744812 sec
#
# Epoch 73 Batch 0 Loss 0.0137
# Epoch 73 Batch 10 Loss 0.0121
# Epoch 73 Batch 20 Loss 0.0109
# Epoch 73 Batch 30 Loss 0.0132
# Epoch 73 Batch 40 Loss 0.0211
# Epoch 73 Batch 50 Loss 0.0157
# Epoch 73 Batch 60 Loss 0.0150
# Epoch 73 Batch 70 Loss 0.0155
# Epoch 73 Batch 80 Loss 0.0176
# Epoch 73 Batch 90 Loss 0.0149
# Epoch 73 Batch 100 Loss 0.0154
# Epoch 73 Batch 110 Loss 0.0151
# Epoch 73 Batch 120 Loss 0.0145
# Epoch 73 Batch 130 Loss 0.0117
# Epoch 73 Batch 140 Loss 0.0142
# Epoch 73 Batch 150 Loss 0.0145
# Epoch 73 Loss 0.0151
# Time taken for 73 epoch 53.52600884437561 sec
#
# Epoch 74 Batch 0 Loss 0.0065
# Epoch 74 Batch 10 Loss 0.0078
# Epoch 74 Batch 20 Loss 0.0051
# Epoch 74 Batch 30 Loss 0.0061
# Epoch 74 Batch 40 Loss 0.0068
# Epoch 74 Batch 50 Loss 0.0096
# Epoch 74 Batch 60 Loss 0.0080
# Epoch 74 Batch 70 Loss 0.0089
# Epoch 74 Batch 80 Loss 0.0052
# Epoch 74 Batch 90 Loss 0.0076
# Epoch 74 Batch 100 Loss 0.0058
# Epoch 74 Batch 110 Loss 0.0057
# Epoch 74 Batch 120 Loss 0.0068
# Epoch 74 Batch 130 Loss 0.0073
# Epoch 74 Batch 140 Loss 0.0065
# Epoch 74 Batch 150 Loss 0.0061
# Epoch 74 Loss 0.0065
# Time taken for 74 epoch 53.56022262573242 sec
#
# Epoch 75 Batch 0 Loss 0.0021
# Epoch 75 Batch 10 Loss 0.0027
# Epoch 75 Batch 20 Loss 0.0017
# Epoch 75 Batch 30 Loss 0.0019
# Epoch 75 Batch 40 Loss 0.0019
# Epoch 75 Batch 50 Loss 0.0027
# Epoch 75 Batch 60 Loss 0.0020
# Epoch 75 Batch 70 Loss 0.0017
# Epoch 75 Batch 80 Loss 0.0015
# Epoch 75 Batch 90 Loss 0.0018
# Epoch 75 Batch 100 Loss 0.0015
# Epoch 75 Batch 110 Loss 0.0012
# Epoch 75 Batch 120 Loss 0.0019
# Epoch 75 Batch 130 Loss 0.0020
# Epoch 75 Batch 140 Loss 0.0017
# Epoch 75 Batch 150 Loss 0.0011
# Epoch 75 Loss 0.0020
# Time taken for 75 epoch 53.57274079322815 sec
#
# Epoch 76 Batch 0 Loss 0.0008
# Epoch 76 Batch 10 Loss 0.0007
# Epoch 76 Batch 20 Loss 0.0018
# Epoch 76 Batch 30 Loss 0.0008
# Epoch 76 Batch 40 Loss 0.0009
# Epoch 76 Batch 50 Loss 0.0008
# Epoch 76 Batch 60 Loss 0.0008
# Epoch 76 Batch 70 Loss 0.0008
# Epoch 76 Batch 80 Loss 0.0008
# Epoch 76 Batch 90 Loss 0.0009
# Epoch 76 Batch 100 Loss 0.0008
# Epoch 76 Batch 110 Loss 0.0007
# Epoch 76 Batch 120 Loss 0.0008
# Epoch 76 Batch 130 Loss 0.0008
# Epoch 76 Batch 140 Loss 0.0007
# Epoch 76 Batch 150 Loss 0.0008
# Epoch 76 Loss 0.0008
# Time taken for 76 epoch 53.55064678192139 sec
#
# Epoch 77 Batch 0 Loss 0.0005
# Epoch 77 Batch 10 Loss 0.0005
# Epoch 77 Batch 20 Loss 0.0005
# Epoch 77 Batch 30 Loss 0.0006
# Epoch 77 Batch 40 Loss 0.0005
# Epoch 77 Batch 50 Loss 0.0009
# Epoch 77 Batch 60 Loss 0.0005
# Epoch 77 Batch 70 Loss 0.0006
# Epoch 77 Batch 80 Loss 0.0004
# Epoch 77 Batch 90 Loss 0.0005
# Epoch 77 Batch 100 Loss 0.0006
# Epoch 77 Batch 110 Loss 0.0005
# Epoch 77 Batch 120 Loss 0.0006
# Epoch 77 Batch 130 Loss 0.0005
# Epoch 77 Batch 140 Loss 0.0005
# Epoch 77 Batch 150 Loss 0.0005
# Epoch 77 Loss 0.0006
# Time taken for 77 epoch 53.55144906044006 sec
#
# Epoch 78 Batch 0 Loss 0.0004
# Epoch 78 Batch 10 Loss 0.0004
# Epoch 78 Batch 20 Loss 0.0004
# Epoch 78 Batch 30 Loss 0.0004
# Epoch 78 Batch 40 Loss 0.0005
# Epoch 78 Batch 50 Loss 0.0003
# Epoch 78 Batch 60 Loss 0.0004
# Epoch 78 Batch 70 Loss 0.0005
# Epoch 78 Batch 80 Loss 0.0004
# Epoch 78 Batch 90 Loss 0.0005
# Epoch 78 Batch 100 Loss 0.0004
# Epoch 78 Batch 110 Loss 0.0004
# Epoch 78 Batch 120 Loss 0.0005
# Epoch 78 Batch 130 Loss 0.0004
# Epoch 78 Batch 140 Loss 0.0005
# Epoch 78 Batch 150 Loss 0.0004
# Epoch 78 Loss 0.0004
# Time taken for 78 epoch 53.539207458496094 sec
#
# Epoch 79 Batch 0 Loss 0.0003
# Epoch 79 Batch 10 Loss 0.0003
# Epoch 79 Batch 20 Loss 0.0004
# Epoch 79 Batch 30 Loss 0.0004
# Epoch 79 Batch 40 Loss 0.0004
# Epoch 79 Batch 50 Loss 0.0004
# Epoch 79 Batch 60 Loss 0.0003
# Epoch 79 Batch 70 Loss 0.0007
# Epoch 79 Batch 80 Loss 0.0004
# Epoch 79 Batch 90 Loss 0.0003
# Epoch 79 Batch 100 Loss 0.0005
# Epoch 79 Batch 110 Loss 0.0003
# Epoch 79 Batch 120 Loss 0.0003
# Epoch 79 Batch 130 Loss 0.0004
# Epoch 79 Batch 140 Loss 0.0003
# Epoch 79 Batch 150 Loss 0.0003
# Epoch 79 Loss 0.0004
# Time taken for 79 epoch 53.57879614830017 sec
#
# Epoch 80 Batch 0 Loss 0.0003
# Epoch 80 Batch 10 Loss 0.0003
# Epoch 80 Batch 20 Loss 0.0003
# Epoch 80 Batch 30 Loss 0.0003
# Epoch 80 Batch 40 Loss 0.0003
# Epoch 80 Batch 50 Loss 0.0003
# Epoch 80 Batch 60 Loss 0.0003
# Epoch 80 Batch 70 Loss 0.0003
# Epoch 80 Batch 80 Loss 0.0003
# Epoch 80 Batch 90 Loss 0.0003
# Epoch 80 Batch 100 Loss 0.0004
# Epoch 80 Batch 110 Loss 0.0003
# Epoch 80 Batch 120 Loss 0.0004
# Epoch 80 Batch 130 Loss 0.0003
# Epoch 80 Batch 140 Loss 0.0003
# Epoch 80 Batch 150 Loss 0.0003
# Epoch 80 Loss 0.0003
# Time taken for 80 epoch 53.574217081069946 sec
#
# Epoch 81 Batch 0 Loss 0.0004
# Epoch 81 Batch 10 Loss 0.0003
# Epoch 81 Batch 20 Loss 0.0003
# Epoch 81 Batch 30 Loss 0.0004
# Epoch 81 Batch 40 Loss 0.0003
# Epoch 81 Batch 50 Loss 0.0003
# Epoch 81 Batch 60 Loss 0.0003
# Epoch 81 Batch 70 Loss 0.0003
# Epoch 81 Batch 80 Loss 0.0003
# Epoch 81 Batch 90 Loss 0.0003
# Epoch 81 Batch 100 Loss 0.0003
# Epoch 81 Batch 110 Loss 0.0003
# Epoch 81 Batch 120 Loss 0.0003
# Epoch 81 Batch 130 Loss 0.0004
# Epoch 81 Batch 140 Loss 0.0003
# Epoch 81 Batch 150 Loss 0.0003
# Epoch 81 Loss 0.0003
# Time taken for 81 epoch 53.55815505981445 sec
#
# Epoch 82 Batch 0 Loss 0.0003
# Epoch 82 Batch 10 Loss 0.0003
# Epoch 82 Batch 20 Loss 0.0002
# Epoch 82 Batch 30 Loss 0.0002
# Epoch 82 Batch 40 Loss 0.0003
# Epoch 82 Batch 50 Loss 0.0003
# Epoch 82 Batch 60 Loss 0.0002
# Epoch 82 Batch 70 Loss 0.0003
# Epoch 82 Batch 80 Loss 0.0003
# Epoch 82 Batch 90 Loss 0.0003
# Epoch 82 Batch 100 Loss 0.0003
# Epoch 82 Batch 110 Loss 0.0003
# Epoch 82 Batch 120 Loss 0.0003
# Epoch 82 Batch 130 Loss 0.0003
# Epoch 82 Batch 140 Loss 0.0003
# Epoch 82 Batch 150 Loss 0.0002
# Epoch 82 Loss 0.0003
# Time taken for 82 epoch 53.53966474533081 sec
#
# Epoch 83 Batch 0 Loss 0.0003
# Epoch 83 Batch 10 Loss 0.0003
# Epoch 83 Batch 20 Loss 0.0003
# Epoch 83 Batch 30 Loss 0.0003
# Epoch 83 Batch 40 Loss 0.0002
# Epoch 83 Batch 50 Loss 0.0003
# Epoch 83 Batch 60 Loss 0.0002
# Epoch 83 Batch 70 Loss 0.0003
# Epoch 83 Batch 80 Loss 0.0003
# Epoch 83 Batch 90 Loss 0.0003
# Epoch 83 Batch 100 Loss 0.0003
# Epoch 83 Batch 110 Loss 0.0003
# Epoch 83 Batch 120 Loss 0.0002
# Epoch 83 Batch 130 Loss 0.0003
# Epoch 83 Batch 140 Loss 0.0003
# Epoch 83 Batch 150 Loss 0.0003
# Epoch 83 Loss 0.0003
# Time taken for 83 epoch 53.567485332489014 sec
#
# Epoch 84 Batch 0 Loss 0.0003
# Epoch 84 Batch 10 Loss 0.0003
# Epoch 84 Batch 20 Loss 0.0003
# Epoch 84 Batch 30 Loss 0.0002
# Epoch 84 Batch 40 Loss 0.0002
# Epoch 84 Batch 50 Loss 0.0002
# Epoch 84 Batch 60 Loss 0.0003
# Epoch 84 Batch 70 Loss 0.0002
# Epoch 84 Batch 80 Loss 0.0003
# Epoch 84 Batch 90 Loss 0.0003
# Epoch 84 Batch 100 Loss 0.0002
# Epoch 84 Batch 110 Loss 0.0003
# Epoch 84 Batch 120 Loss 0.0003
# Epoch 84 Batch 130 Loss 0.0003
# Epoch 84 Batch 140 Loss 0.0002
# Epoch 84 Batch 150 Loss 0.0003
# Epoch 84 Loss 0.0003
# Time taken for 84 epoch 53.52616620063782 sec
#
# Epoch 85 Batch 0 Loss 0.0002
# Epoch 85 Batch 10 Loss 0.0002
# Epoch 85 Batch 20 Loss 0.0002
# Epoch 85 Batch 30 Loss 0.0002
# Epoch 85 Batch 40 Loss 0.0002
# Epoch 85 Batch 50 Loss 0.0002
# Epoch 85 Batch 60 Loss 0.0003
# Epoch 85 Batch 70 Loss 0.0003
# Epoch 85 Batch 80 Loss 0.0002
# Epoch 85 Batch 90 Loss 0.0002
# Epoch 85 Batch 100 Loss 0.0002
# Epoch 85 Batch 110 Loss 0.0002
# Epoch 85 Batch 120 Loss 0.0003
# Epoch 85 Batch 130 Loss 0.0002
# Epoch 85 Batch 140 Loss 0.0002
# Epoch 85 Batch 150 Loss 0.0002
# Epoch 85 Loss 0.0002
# Time taken for 85 epoch 53.53248357772827 sec
#
# Epoch 86 Batch 0 Loss 0.0002
# Epoch 86 Batch 10 Loss 0.0003
# Epoch 86 Batch 20 Loss 0.0002
# Epoch 86 Batch 30 Loss 0.0003
# Epoch 86 Batch 40 Loss 0.0001
# Epoch 86 Batch 50 Loss 0.0002
# Epoch 86 Batch 60 Loss 0.0002
# Epoch 86 Batch 70 Loss 0.0002
# Epoch 86 Batch 80 Loss 0.0002
# Epoch 86 Batch 90 Loss 0.0002
# Epoch 86 Batch 100 Loss 0.0002
# Epoch 86 Batch 110 Loss 0.0002
# Epoch 86 Batch 120 Loss 0.0002
# Epoch 86 Batch 130 Loss 0.0003
# Epoch 86 Batch 140 Loss 0.0002
# Epoch 86 Batch 150 Loss 0.0002
# Epoch 86 Loss 0.0002
# Time taken for 86 epoch 53.5615336894989 sec
#
# Epoch 87 Batch 0 Loss 0.0002
# Epoch 87 Batch 10 Loss 0.0002
# Epoch 87 Batch 20 Loss 0.0002
# Epoch 87 Batch 30 Loss 0.0002
# Epoch 87 Batch 40 Loss 0.0002
# Epoch 87 Batch 50 Loss 0.0003
# Epoch 87 Batch 60 Loss 0.0002
# Epoch 87 Batch 70 Loss 0.0003
# Epoch 87 Batch 80 Loss 0.0002
# Epoch 87 Batch 90 Loss 0.0002
# Epoch 87 Batch 100 Loss 0.0002
# Epoch 87 Batch 110 Loss 0.0003
# Epoch 87 Batch 120 Loss 0.0002
# Epoch 87 Batch 130 Loss 0.0002
# Epoch 87 Batch 140 Loss 0.0002
# Epoch 87 Batch 150 Loss 0.0002
# Epoch 87 Loss 0.0002
# Time taken for 87 epoch 53.594459772109985 sec
#
# Epoch 88 Batch 0 Loss 0.0002
# ...
#
# Epoch 173 Batch 0 Loss 0.0000
# Epoch 173 Batch 10 Loss 0.0000
# Epoch 173 Batch 20 Loss 0.0000
# Epoch 173 Batch 30 Loss 0.0000
# Epoch 173 Batch 40 Loss 0.0000
# Epoch 173 Batch 50 Loss 0.0000
# Epoch 173 Batch 60 Loss 0.0000
# Epoch 173 Batch 70 Loss 0.0000
# Epoch 173 Batch 80 Loss 0.0000
# Epoch 173 Batch 90 Loss 0.0000
# Epoch 173 Batch 100 Loss 0.0000
# Epoch 173 Batch 110 Loss 0.0000
# Epoch 173 Batch 120 Loss 0.0000
# Epoch 173 Batch 130 Loss 0.0000
# Epoch 173 Batch 140 Loss 0.0000
# Epoch 173 Batch 150 Loss 0.0000
# Epoch 173 Loss 0.0000
# Time taken for 173 epoch 53.56427574157715 sec
#
# Epoch 174 Batch 0 Loss 0.0000
# Epoch 174 Batch 10 Loss 0.0000
# Epoch 174 Batch 20 Loss 0.0000
# Epoch 174 Batch 30 Loss 0.0000
# Epoch 174 Batch 40 Loss 0.0000
# Epoch 174 Batch 50 Loss 0.0000
# Epoch 174 Batch 60 Loss 0.0000
# Epoch 174 Batch 70 Loss 0.0000
# Epoch 174 Batch 80 Loss 0.0000
# Epoch 174 Batch 90 Loss 0.0000
# Epoch 174 Batch 100 Loss 0.0000
# Epoch 174 Batch 110 Loss 0.0000
# Epoch 174 Batch 120 Loss 0.0000
# Epoch 174 Batch 130 Loss 0.0000
# Epoch 174 Batch 140 Loss 0.0000
# Epoch 174 Batch 150 Loss 0.0000
# Epoch 174 Loss 0.0000
# Time taken for 174 epoch 53.57211780548096 sec
#
# Epoch 175 Batch 0 Loss 0.0000
# Epoch 175 Batch 10 Loss 0.0000
# Epoch 175 Batch 20 Loss 0.0000
# Epoch 175 Batch 30 Loss 0.0000
# Epoch 175 Batch 40 Loss 0.0000
# Epoch 175 Batch 50 Loss 0.0000
# Epoch 175 Batch 60 Loss 0.0000
# Epoch 175 Batch 70 Loss 0.0000
# Epoch 175 Batch 80 Loss 0.0000
# Epoch 175 Batch 90 Loss 0.0000
# Epoch 175 Batch 100 Loss 0.0000
# Epoch 175 Batch 110 Loss 0.0000
# Epoch 175 Batch 120 Loss 0.0000
# Epoch 175 Batch 130 Loss 0.0000
# Epoch 175 Batch 140 Loss 0.0000
# Epoch 175 Batch 150 Loss 0.0000
# Epoch 175 Loss 0.0000
# Time taken for 175 epoch 53.541011571884155 sec
#
# Epoch 176 Batch 0 Loss 0.0000
# Epoch 176 Batch 10 Loss 0.0000
# Epoch 176 Batch 20 Loss 0.0000
# Epoch 176 Batch 30 Loss 0.0000
# Epoch 176 Batch 40 Loss 0.0000
# Epoch 176 Batch 50 Loss 0.0000
# Epoch 176 Batch 60 Loss 0.0000
# Epoch 176 Batch 70 Loss 0.0000
# Epoch 176 Batch 80 Loss 0.0000
# Epoch 176 Batch 90 Loss 0.0000
# Epoch 176 Batch 100 Loss 0.0000
# Epoch 176 Batch 110 Loss 0.0000
# Epoch 176 Batch 120 Loss 0.0000
# Epoch 176 Batch 130 Loss 0.0000
# Epoch 176 Batch 140 Loss 0.0000
# Epoch 176 Batch 150 Loss 0.0000
# Epoch 176 Loss 0.0000
# Time taken for 176 epoch 53.56009268760681 sec
#
# Epoch 177 Batch 0 Loss 0.0000
# Epoch 177 Batch 10 Loss 0.0000
# Epoch 177 Batch 20 Loss 0.0000
# Epoch 177 Batch 30 Loss 0.0000
# Epoch 177 Batch 40 Loss 0.0000
# Epoch 177 Batch 50 Loss 0.0000
# Epoch 177 Batch 60 Loss 0.0000
# Epoch 177 Batch 70 Loss 0.0000
# Epoch 177 Batch 80 Loss 0.0000
# Epoch 177 Batch 90 Loss 0.0000
# Epoch 177 Batch 100 Loss 0.0000
# Epoch 177 Batch 110 Loss 0.0000
# Epoch 177 Batch 120 Loss 0.0000
# Epoch 177 Batch 130 Loss 0.0000
# Epoch 177 Batch 140 Loss 0.0000
# Epoch 177 Batch 150 Loss 0.0000
# Epoch 177 Loss 0.0000
# Time taken for 177 epoch 53.56541728973389 sec
#
# Epoch 178 Batch 0 Loss 0.0000
# Epoch 178 Batch 10 Loss 0.0000
# Epoch 178 Batch 20 Loss 0.0000
# Epoch 178 Batch 30 Loss 0.0000
# Epoch 178 Batch 40 Loss 0.0000
# Epoch 178 Batch 50 Loss 0.0000
# Epoch 178 Batch 60 Loss 0.0000
# Epoch 178 Batch 70 Loss 0.0000
# Epoch 178 Batch 80 Loss 0.0000
# Epoch 178 Batch 90 Loss 0.0000
# Epoch 178 Batch 100 Loss 0.0000
# Epoch 178 Batch 110 Loss 0.0000
# Epoch 178 Batch 120 Loss 0.0000
# Epoch 178 Batch 130 Loss 0.0000
# Epoch 178 Batch 140 Loss 0.0000
# Epoch 178 Batch 150 Loss 0.0000
# Epoch 178 Loss 0.0000
# Time taken for 178 epoch 53.55962061882019 sec
#
# Epoch 179 Batch 0 Loss 0.0000
# Epoch 179 Batch 10 Loss 0.0000
# Epoch 179 Batch 20 Loss 0.0000
# Epoch 179 Batch 30 Loss 0.0000
# Epoch 179 Batch 40 Loss 0.0000
# Epoch 179 Batch 50 Loss 0.0000
# Epoch 179 Batch 60 Loss 0.0000
# Epoch 179 Batch 70 Loss 0.0000
# Epoch 179 Batch 80 Loss 0.0000
# Epoch 179 Batch 90 Loss 0.0000
# Epoch 179 Batch 100 Loss 0.0000
# Epoch 179 Batch 110 Loss 0.0000
# Epoch 179 Batch 120 Loss 0.0000
# Epoch 179 Batch 130 Loss 0.0000
# Epoch 179 Batch 140 Loss 0.0000
# Epoch 179 Batch 150 Loss 0.0000
# Epoch 179 Loss 0.0000
# Time taken for 179 epoch 53.54934597015381 sec
#
# Epoch 180 Batch 0 Loss 0.0000
# Epoch 180 Batch 10 Loss 0.0000
# Epoch 180 Batch 20 Loss 0.0000
# Epoch 180 Batch 30 Loss 0.0000
# Epoch 180 Batch 40 Loss 0.0000
# Epoch 180 Batch 50 Loss 0.0000
# Epoch 180 Batch 60 Loss 0.0000
# Epoch 180 Batch 70 Loss 0.0000
# Epoch 180 Batch 80 Loss 0.0000
# Epoch 180 Batch 90 Loss 0.0000
# Epoch 180 Batch 100 Loss 0.0000
# Epoch 180 Batch 110 Loss 0.0000
# Epoch 180 Batch 120 Loss 0.0000
# Epoch 180 Batch 130 Loss 0.0000
# Epoch 180 Batch 140 Loss 0.0000
# Epoch 180 Batch 150 Loss 0.0000
# Epoch 180 Loss 0.0000
# Time taken for 180 epoch 53.55299210548401 sec
#
# Epoch 181 Batch 0 Loss 0.0000
# Epoch 181 Batch 10 Loss 0.0000
# Epoch 181 Batch 20 Loss 0.0000
# Epoch 181 Batch 30 Loss 0.0000
# Epoch 181 Batch 40 Loss 0.0000
# Epoch 181 Batch 50 Loss 0.0000
# Epoch 181 Batch 60 Loss 0.0000
# Epoch 181 Batch 70 Loss 0.0000
# Epoch 181 Batch 80 Loss 0.0000
# Epoch 181 Batch 90 Loss 0.0000
# Epoch 181 Batch 100 Loss 0.0000
# Epoch 181 Batch 110 Loss 0.0000
# Epoch 181 Batch 120 Loss 0.0000
# Epoch 181 Batch 130 Loss 0.0000
# Epoch 181 Batch 140 Loss 0.0000
# Epoch 181 Batch 150 Loss 0.0000
# Epoch 181 Loss 0.0000
# Time taken for 181 epoch 53.56054735183716 sec
#
# Epoch 182 Batch 0 Loss 0.0000
# Epoch 182 Batch 10 Loss 0.0000
# Epoch 182 Batch 20 Loss 0.0000
# Epoch 182 Batch 30 Loss 0.0000
# Epoch 182 Batch 40 Loss 0.0000
# Epoch 182 Batch 50 Loss 0.0000
# Epoch 182 Batch 60 Loss 0.0000
# Epoch 182 Batch 70 Loss 0.0000
# Epoch 182 Batch 80 Loss 0.0000
# Epoch 182 Batch 90 Loss 0.0000
# Epoch 182 Batch 100 Loss 0.0000
# Epoch 182 Batch 110 Loss 0.0000
# Epoch 182 Batch 120 Loss 0.0000
# Epoch 182 Batch 130 Loss 0.0000
# Epoch 182 Batch 140 Loss 0.0000
# Epoch 182 Batch 150 Loss 0.0000
# Epoch 182 Loss 0.0000
# Time taken for 182 epoch 53.58635234832764 sec
#
# Epoch 183 Batch 0 Loss 0.0000
# Epoch 183 Batch 10 Loss 0.0000
# Epoch 183 Batch 20 Loss 0.0000
# Epoch 183 Batch 30 Loss 0.0000
# Epoch 183 Batch 40 Loss 0.0000
# Epoch 183 Batch 50 Loss 0.0000
# Epoch 183 Batch 60 Loss 0.0000
# Epoch 183 Batch 70 Loss 0.0000
# Epoch 183 Batch 80 Loss 0.0000
# Epoch 183 Batch 90 Loss 0.0000
# Epoch 183 Batch 100 Loss 0.0000
# Epoch 183 Batch 110 Loss 0.0000
# Epoch 183 Batch 120 Loss 0.0000
# Epoch 183 Batch 130 Loss 0.0000
# Epoch 183 Batch 140 Loss 0.0000
# Epoch 183 Batch 150 Loss 0.0000
# Epoch 183 Loss 0.0000
# Time taken for 183 epoch 53.560967683792114 sec
#
# Epoch 184 Batch 0 Loss 0.0000
# Epoch 184 Batch 10 Loss 0.0000
# Epoch 184 Batch 20 Loss 0.0000
# Epoch 184 Batch 30 Loss 0.0000
# Epoch 184 Batch 40 Loss 0.0000
# Epoch 184 Batch 50 Loss 0.0000
# Epoch 184 Batch 60 Loss 0.0000
# Epoch 184 Batch 70 Loss 0.0000
# Epoch 184 Batch 80 Loss 0.0000
# Epoch 184 Batch 90 Loss 0.0000
# Epoch 184 Batch 100 Loss 0.0000
# Epoch 184 Batch 110 Loss 0.0000
# Epoch 184 Batch 120 Loss 0.0000
# Epoch 184 Batch 130 Loss 0.0000
# Epoch 184 Batch 140 Loss 0.0000
# Epoch 184 Batch 150 Loss 0.0000
# Epoch 184 Loss 0.0000
# Time taken for 184 epoch 53.59546446800232 sec
#
# Epoch 185 Batch 0 Loss 0.0000
# Epoch 185 Batch 10 Loss 0.0000
# Epoch 185 Batch 20 Loss 0.0000
# Epoch 185 Batch 30 Loss 0.0000
# Epoch 185 Batch 40 Loss 0.0000
# Epoch 185 Batch 50 Loss 0.0000
# Epoch 185 Batch 60 Loss 0.0000
# Epoch 185 Batch 70 Loss 0.0000
# Epoch 185 Batch 80 Loss 0.0000
# Epoch 185 Batch 90 Loss 0.0000
# Epoch 185 Batch 100 Loss 0.0000
# Epoch 185 Batch 110 Loss 0.0000
# Epoch 185 Batch 120 Loss 0.0000
# Epoch 185 Batch 130 Loss 0.0000
# Epoch 185 Batch 140 Loss 0.0000
# Epoch 185 Batch 150 Loss 0.0000
# Epoch 185 Loss 0.0000
# Time taken for 185 epoch 53.56449055671692 sec
#
# Epoch 186 Batch 0 Loss 0.0000
# Epoch 186 Batch 10 Loss 0.0004
# Epoch 186 Batch 20 Loss 0.0060
# Epoch 186 Batch 30 Loss 0.0121
# Epoch 186 Batch 40 Loss 0.0151
# Epoch 186 Batch 50 Loss 0.0092
# Epoch 186 Batch 60 Loss 0.0106
# Epoch 186 Batch 70 Loss 0.0081
# Epoch 186 Batch 80 Loss 0.0059
# Epoch 186 Batch 90 Loss 0.0071
# Epoch 186 Batch 100 Loss 0.0065
# Epoch 186 Batch 110 Loss 0.0089
# Epoch 186 Batch 120 Loss 0.0067
# Epoch 186 Batch 130 Loss 0.0062
# Epoch 186 Batch 140 Loss 0.0054
# Epoch 186 Batch 150 Loss 0.0094
# Epoch 186 Loss 0.0083
# Time taken for 186 epoch 53.573208808898926 sec
#
# Epoch 187 Batch 0 Loss 0.0073
# Epoch 187 Batch 10 Loss 0.0056
# Epoch 187 Batch 20 Loss 0.0067
# Epoch 187 Batch 30 Loss 0.0051
# Epoch 187 Batch 40 Loss 0.0039
# Epoch 187 Batch 50 Loss 0.0025
# Epoch 187 Batch 60 Loss 0.0036
# Epoch 187 Batch 70 Loss 0.0044
# Epoch 187 Batch 80 Loss 0.0082
# Epoch 187 Batch 90 Loss 0.0047
# Epoch 187 Batch 100 Loss 0.0062
# Epoch 187 Batch 110 Loss 0.0036
# Epoch 187 Batch 120 Loss 0.0045
# Epoch 187 Batch 130 Loss 0.0047
# Epoch 187 Batch 140 Loss 0.0028
# Epoch 187 Batch 150 Loss 0.0042
# Epoch 187 Loss 0.0047
# Time taken for 187 epoch 53.57127904891968 sec
#
# Epoch 188 Batch 0 Loss 0.0011
# Epoch 188 Batch 10 Loss 0.0013
# Epoch 188 Batch 20 Loss 0.0015
# Epoch 188 Batch 30 Loss 0.0007
# Epoch 188 Batch 40 Loss 0.0010
# Epoch 188 Batch 50 Loss 0.0009
# Epoch 188 Batch 60 Loss 0.0024
# Epoch 188 Batch 70 Loss 0.0007
# Epoch 188 Batch 80 Loss 0.0006
# Epoch 188 Batch 90 Loss 0.0007
# Epoch 188 Batch 100 Loss 0.0010
# Epoch 188 Batch 110 Loss 0.0042
# Epoch 188 Batch 120 Loss 0.0005
# Epoch 188 Batch 130 Loss 0.0007
# Epoch 188 Batch 140 Loss 0.0025
# Epoch 188 Batch 150 Loss 0.0013
# Epoch 188 Loss 0.0012
# Time taken for 188 epoch 53.57676386833191 sec
#
# Epoch 189 Batch 0 Loss 0.0002
# Epoch 189 Batch 10 Loss 0.0003
# Epoch 189 Batch 20 Loss 0.0002
# Epoch 189 Batch 30 Loss 0.0003
# Epoch 189 Batch 40 Loss 0.0005
# Epoch 189 Batch 50 Loss 0.0004
# Epoch 189 Batch 60 Loss 0.0001
# Epoch 189 Batch 70 Loss 0.0002
# Epoch 189 Batch 80 Loss 0.0005
# Epoch 189 Batch 90 Loss 0.0002
# Epoch 189 Batch 100 Loss 0.0007
# Epoch 189 Batch 110 Loss 0.0001
# Epoch 189 Batch 120 Loss 0.0004
# Epoch 189 Batch 130 Loss 0.0004
# Epoch 189 Batch 140 Loss 0.0003
# Epoch 189 Batch 150 Loss 0.0002
# Epoch 189 Loss 0.0004
# Time taken for 189 epoch 53.58252429962158 sec
#
# Epoch 190 Batch 0 Loss 0.0002
# Epoch 190 Batch 10 Loss 0.0001
# Epoch 190 Batch 20 Loss 0.0002
# Epoch 190 Batch 30 Loss 0.0001
# Epoch 190 Batch 40 Loss 0.0001
# Epoch 190 Batch 50 Loss 0.0001
# Epoch 190 Batch 60 Loss 0.0003
# Epoch 190 Batch 70 Loss 0.0005
# Epoch 190 Batch 80 Loss 0.0003
# Epoch 190 Batch 90 Loss 0.0002
# Epoch 190 Batch 100 Loss 0.0001
# Epoch 190 Batch 110 Loss 0.0001
# Epoch 190 Batch 120 Loss 0.0001
# Epoch 190 Batch 130 Loss 0.0001
# Epoch 190 Batch 140 Loss 0.0001
# Epoch 190 Batch 150 Loss 0.0001
# Epoch 190 Loss 0.0002
# Time taken for 190 epoch 53.56706690788269 sec
#
# Epoch 191 Batch 0 Loss 0.0000
# Epoch 191 Batch 10 Loss 0.0002
# Epoch 191 Batch 20 Loss 0.0001
# Epoch 191 Batch 30 Loss 0.0001
# Epoch 191 Batch 40 Loss 0.0001
# Epoch 191 Batch 50 Loss 0.0000
# Epoch 191 Batch 60 Loss 0.0003
# Epoch 191 Batch 70 Loss 0.0001
# Epoch 191 Batch 80 Loss 0.0001
# Epoch 191 Batch 90 Loss 0.0001
# Epoch 191 Batch 100 Loss 0.0001
# Epoch 191 Batch 110 Loss 0.0001
# Epoch 191 Batch 120 Loss 0.0001
# Epoch 191 Batch 130 Loss 0.0001
# Epoch 191 Batch 140 Loss 0.0001
# Epoch 191 Batch 150 Loss 0.0001
# Epoch 191 Loss 0.0001
# Time taken for 191 epoch 53.54528450965881 sec
#
# Epoch 192 Batch 0 Loss 0.0000
# Epoch 192 Batch 10 Loss 0.0001
# Epoch 192 Batch 20 Loss 0.0000
# Epoch 192 Batch 30 Loss 0.0001
# Epoch 192 Batch 40 Loss 0.0004
# Epoch 192 Batch 50 Loss 0.0000
# Epoch 192 Batch 60 Loss 0.0001
# Epoch 192 Batch 70 Loss 0.0000
# Epoch 192 Batch 80 Loss 0.0001
# Epoch 192 Batch 90 Loss 0.0000
# Epoch 192 Batch 100 Loss 0.0001
# Epoch 192 Batch 110 Loss 0.0000
# Epoch 192 Batch 120 Loss 0.0001
# Epoch 192 Batch 130 Loss 0.0000
# Epoch 192 Batch 140 Loss 0.0000
# Epoch 192 Batch 150 Loss 0.0000
# Epoch 192 Loss 0.0001
# Time taken for 192 epoch 53.54667901992798 sec
#
# Epoch 193 Batch 0 Loss 0.0000
# Epoch 193 Batch 10 Loss 0.0000
# Epoch 193 Batch 20 Loss 0.0000
# Epoch 193 Batch 30 Loss 0.0000
# Epoch 193 Batch 40 Loss 0.0000
# Epoch 193 Batch 50 Loss 0.0000
# Epoch 193 Batch 60 Loss 0.0000
# Epoch 193 Batch 70 Loss 0.0000
# Epoch 193 Batch 80 Loss 0.0000
# Epoch 193 Batch 90 Loss 0.0000
# Epoch 193 Batch 100 Loss 0.0000
# Epoch 193 Batch 110 Loss 0.0000
# Epoch 193 Batch 120 Loss 0.0000
# Epoch 193 Batch 130 Loss 0.0000
# Epoch 193 Batch 140 Loss 0.0000
# Epoch 193 Batch 150 Loss 0.0000
# Epoch 193 Loss 0.0000
# Time taken for 193 epoch 53.53656220436096 sec
#
# Epoch 194 Batch 0 Loss 0.0000
# Epoch 194 Batch 10 Loss 0.0000
# Epoch 194 Batch 20 Loss 0.0000
# Epoch 194 Batch 30 Loss 0.0000
# Epoch 194 Batch 40 Loss 0.0000
# Epoch 194 Batch 50 Loss 0.0001
# Epoch 194 Batch 60 Loss 0.0000
# Epoch 194 Batch 70 Loss 0.0000
# Epoch 194 Batch 80 Loss 0.0000
# Epoch 194 Batch 90 Loss 0.0000
# Epoch 194 Batch 100 Loss 0.0000
# Epoch 194 Batch 110 Loss 0.0000
# Epoch 194 Batch 120 Loss 0.0000
# Epoch 194 Batch 130 Loss 0.0000
# Epoch 194 Batch 140 Loss 0.0000
# Epoch 194 Batch 150 Loss 0.0000
# Epoch 194 Loss 0.0000
# Time taken for 194 epoch 53.59512901306152 sec
#
# Epoch 195 Batch 0 Loss 0.0000
# Epoch 195 Batch 10 Loss 0.0000
# Epoch 195 Batch 20 Loss 0.0000
# Epoch 195 Batch 30 Loss 0.0000
# Epoch 195 Batch 40 Loss 0.0000
# Epoch 195 Batch 50 Loss 0.0000
# Epoch 195 Batch 60 Loss 0.0000
# Epoch 195 Batch 70 Loss 0.0000
# Epoch 195 Batch 80 Loss 0.0000
# Epoch 195 Batch 90 Loss 0.0000
# Epoch 195 Batch 100 Loss 0.0000
# Epoch 195 Batch 110 Loss 0.0000
# Epoch 195 Batch 120 Loss 0.0000
# Epoch 195 Batch 130 Loss 0.0000
# Epoch 195 Batch 140 Loss 0.0000
# Epoch 195 Batch 150 Loss 0.0000
# Epoch 195 Loss 0.0000
# Time taken for 195 epoch 53.57214546203613 sec
#
# Epoch 196 Batch 0 Loss 0.0000
# Epoch 196 Batch 10 Loss 0.0000
# Epoch 196 Batch 20 Loss 0.0000
# Epoch 196 Batch 30 Loss 0.0000
# Epoch 196 Batch 40 Loss 0.0000
# Epoch 196 Batch 50 Loss 0.0000
# Epoch 196 Batch 60 Loss 0.0000
# Epoch 196 Batch 70 Loss 0.0000
# Epoch 196 Batch 80 Loss 0.0000
# Epoch 196 Batch 90 Loss 0.0000
# Epoch 196 Batch 100 Loss 0.0000
# Epoch 196 Batch 110 Loss 0.0000
# Epoch 196 Batch 120 Loss 0.0000
# Epoch 196 Batch 130 Loss 0.0000
# Epoch 196 Batch 140 Loss 0.0000
# Epoch 196 Batch 150 Loss 0.0000
# Epoch 196 Loss 0.0000
# Time taken for 196 epoch 53.591580867767334 sec
#
# Epoch 197 Batch 0 Loss 0.0000
# Epoch 197 Batch 10 Loss 0.0000
# Epoch 197 Batch 20 Loss 0.0000
# Epoch 197 Batch 30 Loss 0.0000
# Epoch 197 Batch 40 Loss 0.0000
# Epoch 197 Batch 50 Loss 0.0000
# Epoch 197 Batch 60 Loss 0.0000
# Epoch 197 Batch 70 Loss 0.0000
# Epoch 197 Batch 80 Loss 0.0000
# Epoch 197 Batch 90 Loss 0.0000
# Epoch 197 Batch 100 Loss 0.0000
# Epoch 197 Batch 110 Loss 0.0000
# Epoch 197 Batch 120 Loss 0.0000
# Epoch 197 Batch 130 Loss 0.0000
# Epoch 197 Batch 140 Loss 0.0000
# Epoch 197 Batch 150 Loss 0.0000
# Epoch 197 Loss 0.0000
# Time taken for 197 epoch 53.57461071014404 sec
#
# Epoch 198 Batch 0 Loss 0.0000
# Epoch 198 Batch 10 Loss 0.0000
# Epoch 198 Batch 20 Loss 0.0000
# Epoch 198 Batch 30 Loss 0.0000
# Epoch 198 Batch 40 Loss 0.0000
# Epoch 198 Batch 50 Loss 0.0000
# Epoch 198 Batch 60 Loss 0.0000
# Epoch 198 Batch 70 Loss 0.0000
# Epoch 198 Batch 80 Loss 0.0000
# Epoch 198 Batch 90 Loss 0.0000
# Epoch 198 Batch 100 Loss 0.0000
# Epoch 198 Batch 110 Loss 0.0000
# Epoch 198 Batch 120 Loss 0.0000
# Epoch 198 Batch 130 Loss 0.0000
# Epoch 198 Batch 140 Loss 0.0000
# Epoch 198 Batch 150 Loss 0.0000
# Epoch 198 Loss 0.0000
# Time taken for 198 epoch 53.538607358932495 sec
#
# Epoch 199 Batch 0 Loss 0.0000
# Epoch 199 Batch 10 Loss 0.0000
# Epoch 199 Batch 20 Loss 0.0000
# Epoch 199 Batch 30 Loss 0.0000
# Epoch 199 Batch 40 Loss 0.0000
# Epoch 199 Batch 50 Loss 0.0000
# Epoch 199 Batch 60 Loss 0.0000
# Epoch 199 Batch 70 Loss 0.0000
# Epoch 199 Batch 80 Loss 0.0000
# Epoch 199 Batch 90 Loss 0.0000
# Epoch 199 Batch 100 Loss 0.0000
# Epoch 199 Batch 110 Loss 0.0000
# Epoch 199 Batch 120 Loss 0.0000
# Epoch 199 Batch 130 Loss 0.0000
# Epoch 199 Batch 140 Loss 0.0000
# Epoch 199 Batch 150 Loss 0.0000
# Epoch 199 Loss 0.0000
# Time taken for 199 epoch 53.55454969406128 sec
#
# Epoch 200 Batch 0 Loss 0.0000
# Epoch 200 Batch 10 Loss 0.0000
# Epoch 200 Batch 20 Loss 0.0000
# Epoch 200 Batch 30 Loss 0.0000
# Epoch 200 Batch 40 Loss 0.0000
# Epoch 200 Batch 50 Loss 0.0000
# Epoch 200 Batch 60 Loss 0.0000
# Epoch 200 Batch 70 Loss 0.0000
# Epoch 200 Batch 80 Loss 0.0000
# Epoch 200 Batch 90 Loss 0.0000
# Epoch 200 Batch 100 Loss 0.0000
# Epoch 200 Batch 110 Loss 0.0000
# Epoch 200 Batch 120 Loss 0.0000
# Epoch 200 Batch 130 Loss 0.0000
# Epoch 200 Batch 140 Loss 0.0000
# Epoch 200 Batch 150 Loss 0.0000
# Epoch 200 Loss 0.0000
# Time taken for 200 epoch 57.38536620140076 sec

# %% [markdown]
# ### Оцениваем модель

# %%
for i in range(5):
  padded_test = trans_2_sum.get_padded()["test"][i]
  text2 = seq2text(padded_test)
  print(f"Original title: {seq2summary(padded_test)}\nPredicted title: {evaluate(text2.strip(), trans_2.get_token(), trans_2_sum.get_token())}\n" )
# Out:
# Original title: или куда полетит
# Predicted title: «мощнейшая» ракета будет порошенко eos
# Original title: «люди в бурятии очень
# Predicted title: «интер» не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в сша не будет в
# Original title: ссср как лукашенко провел выборы
# Predicted title: ягр будет в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша маккейн в сша
# Original title: «он очень об отношениях с молодым
# Predicted title: «все что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша что в сша
# Original title: россию» почему киев не платит пенсии
# Predicted title: «виланова будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет не будет

# %% [markdown]
# # Вывод
#
# 1. При попытки использовать модель _IlyaGusev/rut5_base_sum_gazeta_  результат вышел не очень хороший, потому были попытки использовать более развернутая модель _IlyaGusev/mbart_ru_sum_gazeta_, но и она не дала хороших результатов.
#
# 2. Плохой результат... Походу, переобучение сказалось на модели. По логам обучения видно, что переобучение началось в 80-ых эпохах и в 100-ых эпохах окончательно сошлось все к нулю. По хорошему, надо брать меньше эпох и уменьшить размер бача, тогда может получиться более менее нормальная модель.
